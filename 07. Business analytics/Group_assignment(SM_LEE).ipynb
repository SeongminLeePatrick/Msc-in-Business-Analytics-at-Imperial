# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
ss = pd.read_csv('Dataset/2016-07-metropolitan-stop-and-search.csv')
crime  = pd.read_csv('Dataset/2016-07-metropolitan-crimes.csv')

# %%
datetime = pd.DatetimeIndex(ss['Date'])

# %%
datetime
# Out:
# DatetimeIndex(['2016-06-30 23:02:00', '2016-06-30 23:05:00',
#                '2016-06-30 23:05:00', '2016-06-30 23:10:00',
#                '2016-06-30 23:10:00', '2016-06-30 23:12:00',
#                '2016-06-30 23:20:00', '2016-06-30 23:23:00',
#                '2016-06-30 23:30:00', '2016-06-30 23:34:00',
#                ...
#                '2016-07-31 22:05:00', '2016-07-31 22:15:00',
#                '2016-07-31 22:20:00', '2016-07-31 22:21:00',
#                '2016-07-31 22:35:00', '2016-07-31 22:35:00',
#                '2016-07-31 22:45:00', '2016-07-31 22:50:00',
#                '2016-07-31 22:55:00', '2016-07-31 22:55:00'],
#               dtype='datetime64[ns]', name='Date', length=11962, freq=None)

# %%
ss['month'] = datetime.month
ss['hour'] = datetime.hour

# %%
hour_list = []
for h in ss['hour']:
    if 5 < h <= 10:
        hour_list.append('0501_1000')
    elif 10 < h <= 17:
        hour_list.append('1001_1700')
    elif 17 <  h <= 23:
        hour_list.append('1701_2300')
    else:
        hour_list.append('2301_0500')

# %%
ss['hour_dummies'] = hour_list

# %%
ss.Gender.value_counts()
# Out:
# Male      11036
# Female      766
# Other         7
# Name: Gender, dtype: int64

# %%
ss['Gender_dummies'] = ss.Gender.map({'Male':1, 'Female':0, 'Other':np.nan})

# %%
ss['Age range'].value_counts()
# Out:
# 18-24       4668
# 25-34       2610
# 10-17       2180
# over 34     1941
# under 10       3
# Name: Age range, dtype: int64

# %%
ss.head()
# Out:
#                         Type                       Date  \
# 0              Person search  2016-06-30T23:02:00+00:00
# 1  Person and Vehicle search  2016-06-30T23:05:00+00:00
# 2              Person search  2016-06-30T23:05:00+00:00
# 3  Person and Vehicle search  2016-06-30T23:10:00+00:00
# 4              Person search  2016-06-30T23:10:00+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                         False                 NaN        NaN        NaN
# 1                         False                 NaN  51.479902  -0.433351
# 2                         False                 NaN  51.502729  -0.441156
# 3                         False                 NaN  51.604407  -0.069872
# 4                         False                 NaN  51.497555  -0.049637
#
#    Gender Age range                             Self-defined ethnicity  \
# 0    Male     18-24                                    Not Stated (NS)
# 1    Male     18-24  Black or Black British - Any other Black ethni...
# 2  Female     18-24     White - Any other White ethnic background (W9)
# 3    Male     25-34     White - Any other White ethnic background (W9)
# 4    Male     18-24     White - Any other White ethnic background (W9)
#
#   Officer-defined ethnicity  \
# 0                     Asian
# 1                     Black
# 2                     White
# 3                     White
# 4                     White
#
#                                          Legislation  \
# 0              Misuse of Drugs Act 1971 (section 23)
# 1              Misuse of Drugs Act 1971 (section 23)
# 2              Misuse of Drugs Act 1971 (section 23)
# 3  Police and Criminal Evidence Act 1984 (section 1)
# 4  Police and Criminal Evidence Act 1984 (section 1)
#
#                       Object of search                            Outcome  \
# 0                     Controlled drugs  Nothing found - no further action
# 1                     Controlled drugs                   Suspect arrested
# 2                     Controlled drugs  Nothing found - no further action
# 3  Articles for use in criminal damage                   Suspect arrested
# 4  Articles for use in criminal damage  Nothing found - no further action
#
#    Outcome linked to object of search  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Removal of more than just outer clothing  month  hour hour_dummies  \
# 0                                       NaN      6    23    1701_2300
# 1                                       NaN      6    23    1701_2300
# 2                                       NaN      6    23    1701_2300
# 3                                       NaN      6    23    1701_2300
# 4                                       NaN      6    23    1701_2300
#
#    Gender_dummies
# 0             1.0
# 1             1.0
# 2             0.0
# 3             1.0
# 4             1.0

# %%
ss.Type.value_counts()
# Out:
# Person search                9005
# Person and Vehicle search    2793
# Vehicle search                164
# Name: Type, dtype: int64

# %%
def barplot(col):
    Person_search = ss[ss['Type'] == 'Person search'][col].value_counts()
    Person_and_Vehicle_search = ss[ss['Type'] == 'Person and Vehicle search'][col].value_counts()
    Vehicle_search  = ss[ss['Type'] == 'Vehicle search'][col].value_counts()
    df = pd.DataFrame([Person_search, Person_and_Vehicle_search, Vehicle_search])
    df.index = ['Person_search', 'Person_and_Vehicle','Vehicle_search']
    df.plot(kind = 'bar', stacked = False, figsize= (5, 5))

# %%
barplot('hour_dummies')

# %%
barplot('Age range')

# %%
barplot('Gender')

# %%
barplot('Officer-defined ethnicity')

# %% [markdown]
# ## B. Evaluate

# %%
crime.head()
# Out:
#   Crime ID    Month                  Reported by                 Falls within  \
# 0      NaN  2016-07  Metropolitan Police Service  Metropolitan Police Service
# 1      NaN  2016-07  Metropolitan Police Service  Metropolitan Police Service
# 2      NaN  2016-07  Metropolitan Police Service  Metropolitan Police Service
# 3      NaN  2016-07  Metropolitan Police Service  Metropolitan Police Service
# 4      NaN  2016-07  Metropolitan Police Service  Metropolitan Police Service
#
#    Longitude   Latitude                    Location  LSOA code  \
# 0   0.140192  51.582311      On or near Hatch Grove  E01000027
# 1   0.134947  51.588063       On or near Mead Grove  E01000027
# 2   0.140035  51.589112  On or near Beansland Grove  E01000027
# 3   0.137065  51.583672   On or near Police Station  E01000027
# 4   0.140192  51.582311      On or near Hatch Grove  E01000027
#
#                    LSOA name             Crime type Last outcome category  \
# 0  Barking and Dagenham 001A  Anti-social behaviour                   NaN
# 1  Barking and Dagenham 001A  Anti-social behaviour                   NaN
# 2  Barking and Dagenham 001A  Anti-social behaviour                   NaN
# 3  Barking and Dagenham 001A  Anti-social behaviour                   NaN
# 4  Barking and Dagenham 001A  Anti-social behaviour                   NaN
#
#    Context
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
ss['Outcome'].value_counts()
# Out:
# Nothing found - no further action          8062
# Suspect arrested                           2363
# Offender given drugs possession warning    1131
# Offender given penalty notice               226
# Local resolution                             97
# Suspect summonsed to court                   69
# Offender cautioned                           14
# Name: Outcome, dtype: int64

# %%
ss['Outcome linked to object of search'].value_counts()
# Out:
# Series([], Name: Outcome linked to object of search, dtype: int64)

# %%
ss.head()
# Out:
#                         Type                       Date  \
# 0              Person search  2016-06-30T23:02:00+00:00
# 1  Person and Vehicle search  2016-06-30T23:05:00+00:00
# 2              Person search  2016-06-30T23:05:00+00:00
# 3  Person and Vehicle search  2016-06-30T23:10:00+00:00
# 4              Person search  2016-06-30T23:10:00+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                         False                 NaN        NaN        NaN
# 1                         False                 NaN  51.479902  -0.433351
# 2                         False                 NaN  51.502729  -0.441156
# 3                         False                 NaN  51.604407  -0.069872
# 4                         False                 NaN  51.497555  -0.049637
#
#    Gender Age range                             Self-defined ethnicity  \
# 0    Male     18-24                                    Not Stated (NS)
# 1    Male     18-24  Black or Black British - Any other Black ethni...
# 2  Female     18-24     White - Any other White ethnic background (W9)
# 3    Male     25-34     White - Any other White ethnic background (W9)
# 4    Male     18-24     White - Any other White ethnic background (W9)
#
#   Officer-defined ethnicity  \
# 0                     Asian
# 1                     Black
# 2                     White
# 3                     White
# 4                     White
#
#                                          Legislation  \
# 0              Misuse of Drugs Act 1971 (section 23)
# 1              Misuse of Drugs Act 1971 (section 23)
# 2              Misuse of Drugs Act 1971 (section 23)
# 3  Police and Criminal Evidence Act 1984 (section 1)
# 4  Police and Criminal Evidence Act 1984 (section 1)
#
#                       Object of search                            Outcome  \
# 0                     Controlled drugs  Nothing found - no further action
# 1                     Controlled drugs                   Suspect arrested
# 2                     Controlled drugs  Nothing found - no further action
# 3  Articles for use in criminal damage                   Suspect arrested
# 4  Articles for use in criminal damage  Nothing found - no further action
#
#    Outcome linked to object of search  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Removal of more than just outer clothing  month  hour hour_dummies  \
# 0                                       NaN      6    23    1701_2300
# 1                                       NaN      6    23    1701_2300
# 2                                       NaN      6    23    1701_2300
# 3                                       NaN      6    23    1701_2300
# 4                                       NaN      6    23    1701_2300
#
#    Gender_dummies
# 0             1.0
# 1             1.0
# 2             0.0
# 3             1.0
# 4             1.0

# %%
ss.Outcome.value_counts()
# Out:
# Nothing found - no further action          8062
# Suspect arrested                           2363
# Offender given drugs possession warning    1131
# Offender given penalty notice               226
# Local resolution                             97
# Suspect summonsed to court                   69
# Offender cautioned                           14
# Name: Outcome, dtype: int64

# %%
SSO_list = []
for s in ss['Outcome']:
    if s == 'Nothing found - no further action':
        SSO_list.append('nothing')
    else:
        SSO_list.append('something')
ss['SSO'] = SSO_list

# %%
ss['SSO'].value_counts()
# Out:
# nothing      8062
# something    3900
# Name: SSO, dtype: int64

# %%
ss.head()
# Out:
#                         Type                       Date  \
# 0              Person search  2016-06-30T23:02:00+00:00
# 1  Person and Vehicle search  2016-06-30T23:05:00+00:00
# 2              Person search  2016-06-30T23:05:00+00:00
# 3  Person and Vehicle search  2016-06-30T23:10:00+00:00
# 4              Person search  2016-06-30T23:10:00+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                         False                 NaN        NaN        NaN
# 1                         False                 NaN  51.479902  -0.433351
# 2                         False                 NaN  51.502729  -0.441156
# 3                         False                 NaN  51.604407  -0.069872
# 4                         False                 NaN  51.497555  -0.049637
#
#    Gender Age range                             Self-defined ethnicity  \
# 0    Male     18-24                                    Not Stated (NS)
# 1    Male     18-24  Black or Black British - Any other Black ethni...
# 2  Female     18-24     White - Any other White ethnic background (W9)
# 3    Male     25-34     White - Any other White ethnic background (W9)
# 4    Male     18-24     White - Any other White ethnic background (W9)
#
#   Officer-defined ethnicity  \
# 0                     Asian
# 1                     Black
# 2                     White
# 3                     White
# 4                     White
#
#                                          Legislation  \
# 0              Misuse of Drugs Act 1971 (section 23)
# 1              Misuse of Drugs Act 1971 (section 23)
# 2              Misuse of Drugs Act 1971 (section 23)
# 3  Police and Criminal Evidence Act 1984 (section 1)
# 4  Police and Criminal Evidence Act 1984 (section 1)
#
#                       Object of search                            Outcome  \
# 0                     Controlled drugs  Nothing found - no further action
# 1                     Controlled drugs                   Suspect arrested
# 2                     Controlled drugs  Nothing found - no further action
# 3  Articles for use in criminal damage                   Suspect arrested
# 4  Articles for use in criminal damage  Nothing found - no further action
#
#    Outcome linked to object of search  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Removal of more than just outer clothing  month  hour hour_dummies  \
# 0                                       NaN      6    23    1701_2300
# 1                                       NaN      6    23    1701_2300
# 2                                       NaN      6    23    1701_2300
# 3                                       NaN      6    23    1701_2300
# 4                                       NaN      6    23    1701_2300
#
#    Gender_dummies        SSO
# 0             1.0    nothing
# 1             1.0  something
# 2             0.0    nothing
# 3             1.0  something
# 4             1.0    nothing

# %%
c = pd.merge(how='left', left=a, right=b, on= ['Longitude', 'Latitude'])

# %%
b = crime[['Longitude', 'Latitude', 'Location']]

# %%
b.dropna(axis= 0, inplace=True)
# Out:
# c:\users\min\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
c = b.groupby(['Longitude','Latitude']).count()

# %%
def barplot_SSO(col):
    something = ss[ss['SSO'] == 'something'][col].value_counts()
    nothing = ss[ss['SSO'] == 'nothing'][col].value_counts()
    df = pd.DataFrame([something, nothing])
    df.index = ['somthing', 'nothing']
    df.plot(kind = 'bar', stacked = False, figsize= (5, 5))

# %%
ss.columns
# Out:
# Index(['Type', 'Date', 'Part of a policing operation', 'Policing operation',
#        'Latitude', 'Longitude', 'Gender', 'Age range',
#        'Self-defined ethnicity', 'Officer-defined ethnicity', 'Legislation',
#        'Object of search', 'Outcome', 'Outcome linked to object of search',
#        'Removal of more than just outer clothing', 'month', 'hour',
#        'hour_dummies', 'Gender_dummies', 'SSO'],
#       dtype='object')

# %%
ss.Legislation.value_counts()
# Out:
# Misuse of Drugs Act 1971 (section 23)                      7635
# Police and Criminal Evidence Act 1984 (section 1)          3890
# Criminal Justice Act 1988 (section 139B)                    304
# Firearms Act 1968 (section 47)                              131
# Criminal Justice and Public Order Act 1994 (section 60)       2
# Name: Legislation, dtype: int64

# %%
barplot_SSO('Legislation')

# %%
location = pd.read_csv('Dataset/postcode.csv')

# %%
loc = location[['Latitude', 'Longitude','postcode']]

# %%
ss_postcode = pd.merge(how='left', left=ss, right=loc, on= ['Longitude', 'Latitude'])

# %%
ss_postcode.head()
# Out:
#                         Type                       Date  \
# 0              Person search  2016-06-30T23:02:00+00:00
# 1  Person and Vehicle search  2016-06-30T23:05:00+00:00
# 2              Person search  2016-06-30T23:05:00+00:00
# 3  Person and Vehicle search  2016-06-30T23:10:00+00:00
# 4              Person search  2016-06-30T23:10:00+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                         False                 NaN        NaN        NaN
# 1                         False                 NaN  51.479902  -0.433351
# 2                         False                 NaN  51.502729  -0.441156
# 3                         False                 NaN  51.604407  -0.069872
# 4                         False                 NaN  51.497555  -0.049637
#
#    Gender Age range                             Self-defined ethnicity  \
# 0    Male     18-24                                    Not Stated (NS)
# 1    Male     18-24  Black or Black British - Any other Black ethni...
# 2  Female     18-24     White - Any other White ethnic background (W9)
# 3    Male     25-34     White - Any other White ethnic background (W9)
# 4    Male     18-24     White - Any other White ethnic background (W9)
#
#   Officer-defined ethnicity      ...        \
# 0                     Asian      ...
# 1                     Black      ...
# 2                     White      ...
# 3                     White      ...
# 4                     White      ...
#
#                       Object of search                            Outcome  \
# 0                     Controlled drugs  Nothing found - no further action
# 1                     Controlled drugs                   Suspect arrested
# 2                     Controlled drugs  Nothing found - no further action
# 3  Articles for use in criminal damage                   Suspect arrested
# 4  Articles for use in criminal damage  Nothing found - no further action
#
#   Outcome linked to object of search  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    Removal of more than just outer clothing  month  hour  hour_dummies  \
# 0                                       NaN      6    23     1701_2300
# 1                                       NaN      6    23     1701_2300
# 2                                       NaN      6    23     1701_2300
# 3                                       NaN      6    23     1701_2300
# 4                                       NaN      6    23     1701_2300
#
#   Gender_dummies        SSO       postcode
# 0            1.0    nothing              0
# 1            1.0  something          Hayes
# 2            0.0    nothing          Hayes
# 3            1.0  something      Harringay
# 4            1.0    nothing  Bethnal Green
#
# [5 rows x 21 columns]

# %%
len(ss_postcode.postcode.value_counts())
# Out:
# 119

# %%
def barplot_SSO_postcode(col):
    something = ss_postcode[ss_postcode['SSO'] == 'something'][col].value_counts()
    nothing = ss_postcode[ss_postcode['SSO'] == 'nothing'][col].value_counts()
    df = pd.DataFrame([something, nothing])
    df.index = ['somthing', 'nothing']
    df.plot(kind = 'bar', stacked = False, figsize= (5, 5), lengend.l)

# %%
ss_count = ss_postcode.groupby(['postcode']).count()

# %%
ss_postcode
# Out:
#                             Type                       Date  \
# 0                  Person search  2016-06-30T23:02:00+00:00
# 1      Person and Vehicle search  2016-06-30T23:05:00+00:00
# 2                  Person search  2016-06-30T23:05:00+00:00
# 3      Person and Vehicle search  2016-06-30T23:10:00+00:00
# 4                  Person search  2016-06-30T23:10:00+00:00
# 5      Person and Vehicle search  2016-06-30T23:12:00+00:00
# 6                  Person search  2016-06-30T23:20:00+00:00
# 7                  Person search  2016-06-30T23:23:00+00:00
# 8                  Person search  2016-06-30T23:30:00+00:00
# 9                  Person search  2016-06-30T23:34:00+00:00
# 10     Person and Vehicle search  2016-06-30T23:35:00+00:00
# 11                 Person search  2016-06-30T23:35:00+00:00
# 12     Person and Vehicle search  2016-06-30T23:35:00+00:00
# 13                 Person search  2016-06-30T23:45:00+00:00
# 14     Person and Vehicle search  2016-06-30T23:52:00+00:00
# 15                 Person search  2016-06-30T23:53:00+00:00
# 16     Person and Vehicle search  2016-06-30T23:56:00+00:00
# 17                 Person search  2016-06-30T23:56:00+00:00
# 18                Vehicle search  2016-07-01T00:00:00+00:00
# 19                 Person search  2016-07-01T00:00:00+00:00
# 20                 Person search  2016-07-01T00:00:00+00:00
# 21     Person and Vehicle search  2016-07-01T00:00:00+00:00
# 22                 Person search  2016-07-01T00:05:00+00:00
# 23     Person and Vehicle search  2016-07-01T00:10:00+00:00
# 24                 Person search  2016-07-01T00:40:00+00:00
# 25     Person and Vehicle search  2016-07-01T00:45:00+00:00
# 26                 Person search  2016-07-01T01:00:00+00:00
# 27                 Person search  2016-07-01T01:02:00+00:00
# 28                 Person search  2016-07-01T01:05:00+00:00
# 29                 Person search  2016-07-01T01:20:00+00:00
# ...                          ...                        ...
# 11932              Person search  2016-07-31T20:20:00+00:00
# 11933              Person search  2016-07-31T20:24:00+00:00
# 11934              Person search  2016-07-31T20:30:00+00:00
# 11935              Person search  2016-07-31T20:30:00+00:00
# 11936              Person search  2016-07-31T20:30:00+00:00
# 11937  Person and Vehicle search  2016-07-31T20:30:00+00:00
# 11938  Person and Vehicle search  2016-07-31T20:30:00+00:00
# 11939              Person search  2016-07-31T20:30:00+00:00
# 11940              Person search  2016-07-31T20:39:00+00:00
# 11941              Person search  2016-07-31T20:42:00+00:00
# 11942  Person and Vehicle search  2016-07-31T21:05:00+00:00
# 11943              Person search  2016-07-31T21:10:00+00:00
# 11944              Person search  2016-07-31T21:10:00+00:00
# 11945              Person search  2016-07-31T21:10:00+00:00
# 11946              Person search  2016-07-31T21:45:00+00:00
# 11947              Person search  2016-07-31T21:52:00+00:00
# 11948              Person search  2016-07-31T22:00:00+00:00
# 11949              Person search  2016-07-31T22:00:00+00:00
# 11950             Vehicle search  2016-07-31T22:00:00+00:00
# 11951  Person and Vehicle search  2016-07-31T22:00:00+00:00
# 11952  Person and Vehicle search  2016-07-31T22:05:00+00:00
# 11953              Person search  2016-07-31T22:15:00+00:00
# 11954              Person search  2016-07-31T22:20:00+00:00
# 11955  Person and Vehicle search  2016-07-31T22:21:00+00:00
# 11956              Person search  2016-07-31T22:35:00+00:00
# 11957              Person search  2016-07-31T22:35:00+00:00
# 11958              Person search  2016-07-31T22:45:00+00:00
# 11959  Person and Vehicle search  2016-07-31T22:50:00+00:00
# 11960              Person search  2016-07-31T22:55:00+00:00
# 11961              Person search  2016-07-31T22:55:00+00:00
#
#        Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             False                 NaN        NaN        NaN
# 1                             False                 NaN  51.479902  -0.433351
# 2                             False                 NaN  51.502729  -0.441156
# 3                             False                 NaN  51.604407  -0.069872
# 4                             False                 NaN  51.497555  -0.049637
# 5                             False                 NaN  51.418969  -0.147822
# 6                             False                 NaN  51.388965   0.038793
# 7                             False                 NaN  51.466820  -0.085747
# 8                             False                 NaN  51.572151  -0.096839
# 9                             False                 NaN  51.386089   0.042819
# 10                            False                 NaN  51.457474  -0.025940
# 11                            False                 NaN  51.386089   0.042819
# 12                            False                 NaN  51.457474  -0.025940
# 13                            False                 NaN  51.386089   0.042819
# 14                            False                 NaN  51.461004  -0.115876
# 15                            False                 NaN  51.543091  -0.145974
# 16                            False                 NaN  51.425625  -0.009131
# 17                            False                 NaN  51.475228   0.061200
# 18                            False                 NaN  51.425625  -0.009131
# 19                            False                 NaN  51.580526   0.183886
# 20                            False                 NaN  51.532414  -0.115856
# 21                            False                 NaN  51.425625  -0.009131
# 22                            False                 NaN  51.561794  -0.124928
# 23                            False                 NaN  51.463242  -0.111306
# 24                            False                 NaN  51.608680  -0.067250
# 25                            False                 NaN  51.454449  -0.119831
# 26                            False                 NaN  51.412176  -0.303775
# 27                            False                 NaN  51.513992  -0.131821
# 28                            False                 NaN  51.513992  -0.131821
# 29                            False                 NaN  51.464880  -0.113053
# ...                             ...                 ...        ...        ...
# 11932                         False                 NaN  51.552527  -0.345857
# 11933                         False                 NaN  51.553858  -0.294385
# 11934                         False                 NaN  51.464974  -0.130152
# 11935                         False                 NaN  51.378912  -0.200653
# 11936                         False                 NaN  51.378912  -0.200653
# 11937                         False                 NaN  51.378912  -0.200653
# 11938                         False                 NaN  51.378912  -0.200653
# 11939                         False                 NaN  51.378912  -0.200653
# 11940                         False                 NaN  51.556908  -0.298829
# 11941                         False                 NaN  51.493317  -0.227945
# 11942                         False                 NaN  51.495919  -0.364949
# 11943                         False                 NaN  51.512330  -0.133633
# 11944                         False                 NaN  51.445549  -0.022151
# 11945                         False                 NaN        NaN        NaN
# 11946                         False                 NaN  51.586150  -0.091172
# 11947                         False                 NaN        NaN        NaN
# 11948                         False                 NaN        NaN        NaN
# 11949                         False                 NaN  51.427108  -0.358445
# 11950                         False                 NaN  51.553289  -0.097107
# 11951                         False                 NaN  51.530581  -0.122145
# 11952                         False                 NaN  51.528169  -0.131558
# 11953                         False                 NaN  51.558345   0.229061
# 11954                         False                 NaN        NaN        NaN
# 11955                         False                 NaN  51.430913   0.088553
# 11956                         False                 NaN  51.530644  -0.120975
# 11957                         False                 NaN  51.459027  -0.191315
# 11958                         False                 NaN  51.453691   0.036437
# 11959                         False                 NaN  51.530581  -0.122145
# 11960                         False                 NaN  51.557471  -0.288018
# 11961                         False                 NaN  51.530644  -0.120975
#
#        Gender Age range                             Self-defined ethnicity  \
# 0        Male     18-24                                    Not Stated (NS)
# 1        Male     18-24  Black or Black British - Any other Black ethni...
# 2      Female     18-24     White - Any other White ethnic background (W9)
# 3        Male     25-34     White - Any other White ethnic background (W9)
# 4        Male     18-24     White - Any other White ethnic background (W9)
# 5      Female     18-24            Black or Black British - Caribbean (B1)
# 6        Male     10-17                         White - White British (W1)
# 7        Male     18-24              Black or Black British - African (B2)
# 8        Male       NaN  Asian or Asian British - Any other Asian ethni...
# 9        Male     10-17                         White - White British (W1)
# 10     Female     10-17                                    Not Stated (NS)
# 11       Male     18-24                         White - White British (W1)
# 12       Male     10-17  Black or Black British - Any other Black ethni...
# 13       Male     10-17                         White - White British (W1)
# 14       Male     18-24            Black or Black British - Caribbean (B1)
# 15       Male     18-24                                    Not Stated (NS)
# 16       Male     18-24            Black or Black British - Caribbean (B1)
# 17       Male   over 34     White - Any other White ethnic background (W9)
# 18        NaN       NaN                                                NaN
# 19       Male     18-24               Mixed - White and Black African (M2)
# 20       Male     18-24                                    Not Stated (NS)
# 21       Male     18-24  Black or Black British - Any other Black ethni...
# 22       Male   over 34     White - Any other White ethnic background (W9)
# 23       Male     18-24              Black or Black British - African (B2)
# 24       Male     25-34     White - Any other White ethnic background (W9)
# 25       Male     18-24  Asian or Asian British - Any other Asian ethni...
# 26       Male     10-17  Asian or Asian British - Any other Asian ethni...
# 27       Male     18-24  Black or Black British - Any other Black ethni...
# 28       Male     10-17  Black or Black British - Any other Black ethni...
# 29       Male     25-34                                    Not Stated (NS)
# ...       ...       ...                                                ...
# 11932    Male     25-34     White - Any other White ethnic background (W9)
# 11933    Male       NaN                                    Not Stated (NS)
# 11934    Male   over 34  Black or Black British - Any other Black ethni...
# 11935    Male     10-17                         White - White British (W1)
# 11936    Male     10-17                         White - White British (W1)
# 11937    Male     10-17                         White - White British (W1)
# 11938    Male     18-24                         White - White British (W1)
# 11939    Male     18-24                         White - White British (W1)
# 11940    Male       NaN                                    Not Stated (NS)
# 11941    Male     25-34                                    Not Stated (NS)
# 11942    Male   over 34                         White - White British (W1)
# 11943    Male     18-24                         White - White British (W1)
# 11944    Male     18-24            Black or Black British - Caribbean (B1)
# 11945    Male     18-24              Black or Black British - African (B2)
# 11946    Male     18-24  Black or Black British - Any other Black ethni...
# 11947    Male     18-24            Black or Black British - Caribbean (B1)
# 11948    Male     10-17  Black or Black British - Any other Black ethni...
# 11949    Male     25-34     White - Any other White ethnic background (W9)
# 11950     NaN     18-24                                                NaN
# 11951    Male     18-24     White - Any other White ethnic background (W9)
# 11952    Male     18-24  Asian or Asian British - Any other Asian ethni...
# 11953    Male     10-17                         White - White British (W1)
# 11954    Male     18-24            Black or Black British - Caribbean (B1)
# 11955    Male     18-24  Asian or Asian British - Any other Asian ethni...
# 11956    Male   over 34                         White - White British (W1)
# 11957    Male     10-17  Black or Black British - Any other Black ethni...
# 11958    Male     25-34  Black or Black British - Any other Black ethni...
# 11959    Male     18-24          Asian or Asian British - Bangladeshi (A3)
# 11960    Male     18-24          Asian or Asian British - Bangladeshi (A3)
# 11961    Male     18-24     White - Any other White ethnic background (W9)
#
#       Officer-defined ethnicity          ...           \
# 0                         Asian          ...
# 1                         Black          ...
# 2                         White          ...
# 3                         White          ...
# 4                         White          ...
# 5                         Black          ...
# 6                         White          ...
# 7                         Black          ...
# 8                         Asian          ...
# 9                         White          ...
# 10                        Black          ...
# 11                        White          ...
# 12                        Black          ...
# 13                        White          ...
# 14                        Black          ...
# 15                        Black          ...
# 16                        Black          ...
# 17                        White          ...
# 18                          NaN          ...
# 19                        Black          ...
# 20                        Asian          ...
# 21                        Black          ...
# 22                        White          ...
# 23                        Black          ...
# 24                        White          ...
# 25                        Other          ...
# 26                        Asian          ...
# 27                        Black          ...
# 28                        Black          ...
# 29                        Black          ...
# ...                         ...          ...
# 11932                     White          ...
# 11933                     Black          ...
# 11934                     Black          ...
# 11935                     White          ...
# 11936                     White          ...
# 11937                     White          ...
# 11938                     White          ...
# 11939                     White          ...
# 11940                     Black          ...
# 11941                     Black          ...
# 11942                     White          ...
# 11943                     White          ...
# 11944                     Black          ...
# 11945                     Black          ...
# 11946                     Black          ...
# 11947                     Black          ...
# 11948                     Black          ...
# 11949                     White          ...
# 11950                       NaN          ...
# 11951                     White          ...
# 11952                     Asian          ...
# 11953                     White          ...
# 11954                     Black          ...
# 11955                     Asian          ...
# 11956                     White          ...
# 11957                     Black          ...
# 11958                     Black          ...
# 11959                     Asian          ...
# 11960                     Asian          ...
# 11961                     White          ...
#
#                           Object of search  \
# 0                         Controlled drugs
# 1                         Controlled drugs
# 2                         Controlled drugs
# 3      Articles for use in criminal damage
# 4      Articles for use in criminal damage
# 5                         Controlled drugs
# 6                         Controlled drugs
# 7      Articles for use in criminal damage
# 8      Articles for use in criminal damage
# 9      Articles for use in criminal damage
# 10                        Controlled drugs
# 11     Articles for use in criminal damage
# 12                        Controlled drugs
# 13     Articles for use in criminal damage
# 14                        Controlled drugs
# 15                        Controlled drugs
# 16                        Controlled drugs
# 17     Articles for use in criminal damage
# 18                        Controlled drugs
# 19     Articles for use in criminal damage
# 20                        Controlled drugs
# 21                        Controlled drugs
# 22     Articles for use in criminal damage
# 23                        Controlled drugs
# 24     Articles for use in criminal damage
# 25                        Controlled drugs
# 26     Articles for use in criminal damage
# 27     Articles for use in criminal damage
# 28     Articles for use in criminal damage
# 29     Articles for use in criminal damage
# ...                                    ...
# 11932  Articles for use in criminal damage
# 11933                     Controlled drugs
# 11934  Articles for use in criminal damage
# 11935                     Controlled drugs
# 11936  Articles for use in criminal damage
# 11937                     Controlled drugs
# 11938                     Controlled drugs
# 11939                     Controlled drugs
# 11940                     Controlled drugs
# 11941                     Controlled drugs
# 11942                     Controlled drugs
# 11943  Articles for use in criminal damage
# 11944                     Controlled drugs
# 11945  Articles for use in criminal damage
# 11946                     Controlled drugs
# 11947                     Controlled drugs
# 11948  Articles for use in criminal damage
# 11949  Articles for use in criminal damage
# 11950                     Controlled drugs
# 11951                     Controlled drugs
# 11952                     Controlled drugs
# 11953  Articles for use in criminal damage
# 11954                     Controlled drugs
# 11955                     Controlled drugs
# 11956  Articles for use in criminal damage
# 11957  Articles for use in criminal damage
# 11958  Articles for use in criminal damage
# 11959                     Controlled drugs
# 11960                     Controlled drugs
# 11961  Articles for use in criminal damage
#
#                                        Outcome  \
# 0            Nothing found - no further action
# 1                             Suspect arrested
# 2            Nothing found - no further action
# 3                             Suspect arrested
# 4            Nothing found - no further action
# 5      Offender given drugs possession warning
# 6            Nothing found - no further action
# 7                             Suspect arrested
# 8            Nothing found - no further action
# 9                             Suspect arrested
# 10           Nothing found - no further action
# 11                            Suspect arrested
# 12                            Suspect arrested
# 13                            Suspect arrested
# 14           Nothing found - no further action
# 15           Nothing found - no further action
# 16     Offender given drugs possession warning
# 17           Nothing found - no further action
# 18                            Suspect arrested
# 19                            Suspect arrested
# 20           Nothing found - no further action
# 21           Nothing found - no further action
# 22           Nothing found - no further action
# 23     Offender given drugs possession warning
# 24                            Suspect arrested
# 25           Nothing found - no further action
# 26                            Suspect arrested
# 27           Nothing found - no further action
# 28           Nothing found - no further action
# 29           Nothing found - no further action
# ...                                        ...
# 11932        Nothing found - no further action
# 11933        Nothing found - no further action
# 11934        Nothing found - no further action
# 11935        Nothing found - no further action
# 11936        Nothing found - no further action
# 11937        Nothing found - no further action
# 11938        Nothing found - no further action
# 11939        Nothing found - no further action
# 11940        Nothing found - no further action
# 11941               Suspect summonsed to court
# 11942                         Suspect arrested
# 11943        Nothing found - no further action
# 11944        Nothing found - no further action
# 11945                         Suspect arrested
# 11946                         Suspect arrested
# 11947        Nothing found - no further action
# 11948        Nothing found - no further action
# 11949        Nothing found - no further action
# 11950  Offender given drugs possession warning
# 11951                         Suspect arrested
# 11952                         Suspect arrested
# 11953        Nothing found - no further action
# 11954                         Suspect arrested
# 11955        Nothing found - no further action
# 11956        Nothing found - no further action
# 11957        Nothing found - no further action
# 11958        Nothing found - no further action
# 11959                         Suspect arrested
# 11960                         Suspect arrested
# 11961        Nothing found - no further action
#
#       Outcome linked to object of search  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 26                                   NaN
# 27                                   NaN
# 28                                   NaN
# 29                                   NaN
# ...                                  ...
# 11932                                NaN
# 11933                                NaN
# 11934                                NaN
# 11935                                NaN
# 11936                                NaN
# 11937                                NaN
# 11938                                NaN
# 11939                                NaN
# 11940                                NaN
# 11941                                NaN
# 11942                                NaN
# 11943                                NaN
# 11944                                NaN
# 11945                                NaN
# 11946                                NaN
# 11947                                NaN
# 11948                                NaN
# 11949                                NaN
# 11950                                NaN
# 11951                                NaN
# 11952                                NaN
# 11953                                NaN
# 11954                                NaN
# 11955                                NaN
# 11956                                NaN
# 11957                                NaN
# 11958                                NaN
# 11959                                NaN
# 11960                                NaN
# 11961                                NaN
#
#        Removal of more than just outer clothing  month  hour  hour_dummies  \
# 0                                           NaN      6    23     1701_2300
# 1                                           NaN      6    23     1701_2300
# 2                                           NaN      6    23     1701_2300
# 3                                           NaN      6    23     1701_2300
# 4                                           NaN      6    23     1701_2300
# 5                                           NaN      6    23     1701_2300
# 6                                           NaN      6    23     1701_2300
# 7                                           NaN      6    23     1701_2300
# 8                                           NaN      6    23     1701_2300
# 9                                           NaN      6    23     1701_2300
# 10                                          NaN      6    23     1701_2300
# 11                                          NaN      6    23     1701_2300
# 12                                          NaN      6    23     1701_2300
# 13                                          NaN      6    23     1701_2300
# 14                                          NaN      6    23     1701_2300
# 15                                          NaN      6    23     1701_2300
# 16                                          NaN      6    23     1701_2300
# 17                                          NaN      6    23     1701_2300
# 18                                          NaN      7     0     2301_0500
# 19                                          NaN      7     0     2301_0500
# 20                                          NaN      7     0     2301_0500
# 21                                          NaN      7     0     2301_0500
# 22                                          NaN      7     0     2301_0500
# 23                                          NaN      7     0     2301_0500
# 24                                          NaN      7     0     2301_0500
# 25                                          NaN      7     0     2301_0500
# 26                                          NaN      7     1     2301_0500
# 27                                          NaN      7     1     2301_0500
# 28                                          NaN      7     1     2301_0500
# 29                                          NaN      7     1     2301_0500
# ...                                         ...    ...   ...           ...
# 11932                                       NaN      7    20     1701_2300
# 11933                                       NaN      7    20     1701_2300
# 11934                                       NaN      7    20     1701_2300
# 11935                                       NaN      7    20     1701_2300
# 11936                                       NaN      7    20     1701_2300
# 11937                                       NaN      7    20     1701_2300
# 11938                                       NaN      7    20     1701_2300
# 11939                                       NaN      7    20     1701_2300
# 11940                                       NaN      7    20     1701_2300
# 11941                                       NaN      7    20     1701_2300
# 11942                                       NaN      7    21     1701_2300
# 11943                                       NaN      7    21     1701_2300
# 11944                                       NaN      7    21     1701_2300
# 11945                                       NaN      7    21     1701_2300
# 11946                                       NaN      7    21     1701_2300
# 11947                                       NaN      7    21     1701_2300
# 11948                                       NaN      7    22     1701_2300
# 11949                                       NaN      7    22     1701_2300
# 11950                                       NaN      7    22     1701_2300
# 11951                                       NaN      7    22     1701_2300
# 11952                                       NaN      7    22     1701_2300
# 11953                                       NaN      7    22     1701_2300
# 11954                                       NaN      7    22     1701_2300
# 11955                                       NaN      7    22     1701_2300
# 11956                                       NaN      7    22     1701_2300
# 11957                                       NaN      7    22     1701_2300
# 11958                                       NaN      7    22     1701_2300
# 11959                                       NaN      7    22     1701_2300
# 11960                                       NaN      7    22     1701_2300
# 11961                                       NaN      7    22     1701_2300
#
#       Gender_dummies        SSO              postcode
# 0                1.0    nothing                     0
# 1                1.0  something                 Hayes
# 2                0.0    nothing                 Hayes
# 3                1.0  something             Harringay
# 4                1.0    nothing         Bethnal Green
# 5                0.0  something               Mitcham
# 6                1.0    nothing               Bromley
# 7                1.0  something            Camberwell
# 8                1.0    nothing             Harringay
# 9                1.0  something               Bromley
# 10               0.0    nothing               Catford
# 11               1.0  something               Bromley
# 12               1.0  something               Catford
# 13               1.0  something               Bromley
# 14               1.0    nothing               Brixton
# 15               1.0    nothing           Camden Town
# 16               1.0  something               Catford
# 17               1.0    nothing              Woolwich
# 18               NaN  something               Catford
# 19               1.0  something               Romford
# 20               1.0    nothing             Barnsbury
# 21               1.0    nothing               Catford
# 22               1.0    nothing              Holloway
# 23               1.0  something               Brixton
# 24               1.0  something             Harringay
# 25               1.0    nothing          Brixton Hill
# 26               1.0  something  Kingston upon Thames
# 27               1.0    nothing                London
# 28               1.0    nothing                London
# 29               1.0    nothing               Brixton
# ...              ...        ...                   ...
# 11932            1.0    nothing              Northolt
# 11933            1.0    nothing               Wembley
# 11934            1.0    nothing          Brixton Hill
# 11935            1.0    nothing                Morden
# 11936            1.0    nothing                Morden
# 11937            1.0    nothing                Morden
# 11938            1.0    nothing                Morden
# 11939            1.0    nothing                Morden
# 11940            1.0    nothing               Wembley
# 11941            1.0  something           Hammersmith
# 11942            1.0  something              Southall
# 11943            1.0    nothing                London
# 11944            1.0    nothing               Catford
# 11945            1.0  something                     0
# 11946            1.0  something             Harringay
# 11947            1.0    nothing                     0
# 11948            1.0    nothing                     0
# 11949            1.0    nothing               Hampton
# 11950            NaN  something             Islington
# 11951            1.0  something             Barnsbury
# 11952            1.0  something           Camden Town
# 11953            1.0    nothing            Hornchurch
# 11954            1.0  something                     0
# 11955            1.0    nothing                Sidcup
# 11956            1.0    nothing             Barnsbury
# 11957            1.0    nothing            Earlsfield
# 11958            1.0    nothing            Blackheath
# 11959            1.0  something             Barnsbury
# 11960            1.0  something               Wembley
# 11961            1.0    nothing             Barnsbury
#
# [11962 rows x 21 columns]

# %%
ss_postcode.columns
# Out:
# Index(['Type', 'Date', 'Part of a policing operation', 'Policing operation',
#        'Latitude', 'Longitude', 'Gender', 'Age range',
#        'Self-defined ethnicity', 'Officer-defined ethnicity', 'Legislation',
#        'Object of search', 'Outcome', 'Outcome linked to object of search',
#        'Removal of more than just outer clothing', 'month', 'hour',
#        'hour_dummies', 'Gender_dummies', 'SSO', 'postcode'],
#       dtype='object')

# %%
ss_count.sort_values(by=['Type'], ascending=False)['Type']
# Out:
# postcode
# 0                       931
# Harringay               603
# Brixton Hill            453
# Bethnal Green           416
# Hammersmith             410
# London                  404
# Catford                 390
# Kensington              381
# Walthamstow             345
# Camberwell              324
# Poplar                  317
# Hackney                 308
# Brixton                 263
# Bayswater               242
# East Ham                236
# Camden Town             220
# Acton                   192
# Islington               183
# Kennington              182
# Thornton Heath          165
# Wembley                 154
# Battersea               152
# Blackheath              149
# Chelsea                 145
# Kingston upon Thames    141
# Ilford                  136
# Hounslow                123
# Barnsbury               122
# Wood Green              116
# City of Westminster     114
#                        ...
# Ealing Broadway          20
# Collier Row              19
# Chessington              18
# Purley                   17
# Teddington               16
# Hampton                  16
# Isleworth                16
# West Wickham             15
# Hainault                 13
# Belvedere                13
# Hadley Wood              13
# Cheam                    11
# Coulsdon                 11
# Hornchurch                9
# Biggin Hill               8
# Hook                      7
# Ditton Hill               7
# Buckhurst Hill            6
# Dartford                  6
# Iver                      5
# High Barnet               5
# Harefield                 4
# Upminster                 3
# Waltham Abbey             3
# Colnbrook                 3
# Whyteleafe                3
# Halstead                  2
# Warlingham                1
# Borehamwood               1
# Elstree                   1
# Name: Type, Length: 119, dtype: int64

# %%
barplot_SSO_postcode('postcode')
