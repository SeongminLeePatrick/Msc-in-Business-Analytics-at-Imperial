# %% [markdown]
# <br>
# <center>
# <h1>Workforce Analytics</h1>
# <h2><i> - Seongmin Lee(CID: 01247436)  -</i></h2>

# %% [markdown]
# # Author Information on Web of Science (The Number of the authors: 1,813)
#
# example link : http://apps.webofknowledge.com/CitationReport.do?product=WOS&search_mode=CitationReport&SID=D2SJg32DfEVuScBbuYk&page=1&cr_pqid=13&viewType=summary&colName=WOS

# %% [markdown]
# Based on the file named on WOS_scraped_df_ver3.pkl, I could reach the each document's information on the Web of Science directly. If the author's id coloured blue is clicked, then we could reach the author information as depicted below. The dataset could be used to measure the performance of any authors combination.

# %%
from IPython.display import Image
import os
Image(filename = os.getcwd()+'/img/author.jpg')

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import requests
import re
import sys
import time
import csv
from ast import literal_eval
import random

# %% [markdown]
# # Initial Crawling

# %%
def coauthors_info():
    WOS_df = pd.read_pickle('./data/WOS_scraped_df_ver3.pkl')
    WOS_df_set_URL = list(set(WOS_df.WOS_URL))
    
    #Start index designation
    try:
        author_info = pd.read_csv('./data/author_info.csv')
        end_working_url = list(author_info.publication_url)[-1]
        startidx = WOS_df_set_URL.index(end_working_url)+1 
    except:
        author_info = pd.DataFrame(columns=['publication_url','name', 'name_id', 'authors_url', 'ttl_publication', 'h-index', 'avg_citation_per_item', 'sum_of_times_cited', 'without_self_citations', 'citing_articles', 'without_self_citations_article'])
        startidx = 0
       
    for log_count, url in enumerate(WOS_df_set_URL[startidx:]):
        #Ramdonly select the ID 
        ids = ['']
        selected_id = random.choice(ids)
        passwords = ['']
        selected_pass = passwords[ids.index(selected_id)] #

        #log-in page
        chrome_options = Options()
        chrome_options.add_argument('--lang=en-us')
        driver = webdriver.Chrome(chrome_options=chrome_options,executable_path=r"C:/Users/seong/Downloads/chrome/chromedriver")
        driver.get('https://login.webofknowledge.com/error/Error?PathInfo=%2F&Error=IPError')
        driver.implicitly_wait(5)
        driver.find_element_by_name('username').send_keys(selected_id) #email id
        driver.find_element_by_name('password').send_keys(selected_pass) #password
        driver.implicitly_wait(5)
        driver.find_element_by_xpath('//*[@id="WoKerror"]/div/table[2]/tbody/tr/td[2]/form[1]/table/tbody/tr[3]/td[2]/a/button').click() #click
        try:
            driver.find_element_by_xpath('//*[@id="WoKerror"]/div/table[2]/tbody/tr/td[2]/p/a[1]').click() #exception log-in
        except:
            pass
        
        # Reaching the publication page on Web of Science
        driver.get(url)
        driver.implicitly_wait(5)
        
        # Click the bar to see the extra authors
        try:
            driver.find_element_by_xpath('//*[@id="show_more_authors_authors_txt_label"]/a').click()
            driver.implicitly_wait(5)
        except:
            pass
        
        author_info = author_info.astype('object')
        driver.implicitly_wait(5)
        soup = BeautifulSoup(driver.page_source, "html.parser")
        
        #Extract the urls for the author information
        url_parsing = soup.find_all(title=["Find more records by this author"])
        author_parsing = soup.select("a")
        # Parsing author urls
        authors_urls = ['http://apps.webofknowledge.com'+str(u.attrs['href'])for u in url_parsing if bool(re.search(r'[OneClickSearch.do?product=WOS&search_mode]', str(u.attrs['href'])))]                                                                          
        # Parsing the authors names labeld as IDs
        authors_id = [u.string.lower() for u in url_parsing if bool(re.search(r'[OneClickSearch.do?product=WOS&search_mode]', str(u.attrs['href'])))]
        # Parsing the authors names in the parenthesis 
        authors_uniq = []
        for i in author_parsing:
            try:
                if bool(re.search(r'^ \(' ,i.next_sibling)):
                    authors_uniq.append(re.sub('[^A-Za-z0-9, ]+', "", i.next_sibling).strip())
            except:
                pass        

        if len(authors_urls) == 0:
            continue
        
        #Looping the authors' url
        for idx, u in enumerate(authors_urls):
            # Excluding the crawling if the author's id is in the saving dataframe
            if authors_id[idx] in list(author_info.name_id):
                continue
            else:
                #reaching the publication list 
                driver.get(u)
                driver.implicitly_wait(15)
                try:
                    #Click the author summary page button
                    driver.find_element_by_xpath('//*[@id="view_citation_report_image_placeholder"]/div/nobr/a').click()
                    driver.implicitly_wait(15)
                except:
                    continue
                
                citation_report = BeautifulSoup(driver.page_source, "html.parser")
                values = citation_report.find_all('em',{'class':re.compile('[commafy]')})[1:]
                
                #looping the values and saving it as a dataframe
                row_num = author_info.shape[0]
                author_info.loc[row_num,'publication_url'] = url
                author_info.loc[row_num,'name'] = authors_uniq[idx]
                author_info.loc[row_num,'name_id'] = authors_id[idx]
                author_info.loc[row_num,'authors_url'] = str(u)
                print(author_info.loc[row_num,'authors_url'])
                for v, c in zip(values, author_info.columns[4:]):
                    author_info.loc[row_num, c] = v.string.strip().replace(',','')
                print("%sth. %s has been added" %(author_info.shape[0], authors_uniq[idx]))
        author_info.to_csv('./data/author_info.csv', index = None)
        driver.close()
    driver.quit()

# %%
coauthors_info() # 중복이슈
# Out:
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F1QdVqP4kbj5gVLFxNg&author_name=Luft, HS&dais_id=112214&excludeEventConfig=ExcludeIfFromFullRecPage
# 1083th. Luft, Harold S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F1QdVqP4kbj5gVLFxNg&author_name=Guadagnoli, E&dais_id=241787&excludeEventConfig=ExcludeIfFromFullRecPage
# 1084th. Guadagnoli, Edward has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D2ZmxCc1vc3cgDLbfd2&author_name=Bernard, AB&dais_id=902389&excludeEventConfig=ExcludeIfFromFullRecPage
# 1085th. Bernard, Andrew B has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D2ZmxCc1vc3cgDLbfd2&author_name=Massari, R&dais_id=24495206&excludeEventConfig=ExcludeIfFromFullRecPage
# 1086th. Massari, Renzo has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D2ZmxCc1vc3cgDLbfd2&author_name=Reyes, JD&dais_id=6709712&excludeEventConfig=ExcludeIfFromFullRecPage
# 1087th. Reyes, JoseDaniel has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D2ZmxCc1vc3cgDLbfd2&author_name=Taglioni, D&dais_id=4776941&excludeEventConfig=ExcludeIfFromFullRecPage
# 1088th. Taglioni, Daria has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C1KtrcrXrVHqYNtTnpw&author_name=Sivey, P&dais_id=3768482&excludeEventConfig=ExcludeIfFromFullRecPage
# 1089th. Sivey, Peter has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C1KtrcrXrVHqYNtTnpw&author_name=Mason, A&dais_id=642889&excludeEventConfig=ExcludeIfFromFullRecPage
# 1090th. Mason, Anne has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C1Mido211mmcBhcoifD&author_name=Polkovnichenko, V&dais_id=4912097&excludeEventConfig=ExcludeIfFromFullRecPage
# 1091th. Polkovnichenko, Valery has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D5FFT63LfDCpQjuN4ij&author_name=Kellermanns, F&dais_id=6494552&excludeEventConfig=ExcludeIfFromFullRecPage
# 1092th. Kellermanns, Franz has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C5CuFGbl7J7dTv1dmY7&author_name=Bandiera, O&dais_id=1474176&excludeEventConfig=ExcludeIfFromFullRecPage
# 1093th. Bandiera, Oriana has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C5CuFGbl7J7dTv1dmY7&author_name=Prat, A&dais_id=3027926&excludeEventConfig=ExcludeIfFromFullRecPage
# 1094th. Prat, Andrea has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D42JjLRicmpOiMLQvTK&author_name=Ayres, JG&dais_id=37590&excludeEventConfig=ExcludeIfFromFullRecPage
# 1095th. Ayres, J G has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D42JjLRicmpOiMLQvTK&author_name=Janke, K&dais_id=8436226&excludeEventConfig=ExcludeIfFromFullRecPage
# 1096th. Janke, K has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D42JjLRicmpOiMLQvTK&author_name=Harrision, RM&dais_id=26749380&excludeEventConfig=ExcludeIfFromFullRecPage
# 1097th. Harrision, R M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D17QBFE5pPUQ4DUwbZU&author_name=Bruton, G&dais_id=7191473&excludeEventConfig=ExcludeIfFromFullRecPage
# 1098th. Bruton, Garry has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D17QBFE5pPUQ4DUwbZU&author_name=Khavul, S&dais_id=2231517&excludeEventConfig=ExcludeIfFromFullRecPage
# 1099th. Khavul, Susanna has been added
# http://apps.webofknowledge.com/OneClickSearch.do?product=WOS&search_mode=OneClickSearch&excludeEventConfig=ExcludeIfFromFullRecPage&colName=WOS&SID=C61LIyVQXPIHOX2ohNG&field=AU&value=Nugent, R
# 1100th. Nugent, Rachel has been added
# http://apps.webofknowledge.com/OneClickSearch.do?product=WOS&search_mode=OneClickSearch&excludeEventConfig=ExcludeIfFromFullRecPage&colName=WOS&SID=C61LIyVQXPIHOX2ohNG&field=AU&value=Bertram, MY
# 1101th. Bertram, Melanie Y has been added
# http://apps.webofknowledge.com/OneClickSearch.do?product=WOS&search_mode=OneClickSearch&excludeEventConfig=ExcludeIfFromFullRecPage&colName=WOS&SID=C61LIyVQXPIHOX2ohNG&field=AU&value=Jan, S
# 1102th. Jan, Stephen has been added
# http://apps.webofknowledge.com/OneClickSearch.do?product=WOS&search_mode=OneClickSearch&excludeEventConfig=ExcludeIfFromFullRecPage&colName=WOS&SID=C61LIyVQXPIHOX2ohNG&field=AU&value=Niessen, LW
# 1103th. Niessen, Louis W has been added
# http://apps.webofknowledge.com/OneClickSearch.do?product=WOS&search_mode=OneClickSearch&excludeEventConfig=ExcludeIfFromFullRecPage&colName=WOS&SID=C61LIyVQXPIHOX2ohNG&field=AU&value=Jamison, DT
# 1104th. Jamison, Dean T has been added
# http://apps.webofknowledge.com/OneClickSearch.do?product=WOS&search_mode=OneClickSearch&excludeEventConfig=ExcludeIfFromFullRecPage&colName=WOS&SID=C61LIyVQXPIHOX2ohNG&field=AU&value=Pier, EG
# 1105th. Pier, Eduardo Gonzalez has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D4Fd6zTUhgN8f6sLcdQ&author_name=Sayal, K&dais_id=319188&excludeEventConfig=ExcludeIfFromFullRecPage
# 1106th. Sayal, Kapil has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C6cNBTj6kgBBiSesTKE&author_name=Hattula, JD&dais_id=15965598&excludeEventConfig=ExcludeIfFromFullRecPage
# 1107th. Hattula, Johannes D has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C6cNBTj6kgBBiSesTKE&author_name=Schmitz, C&dais_id=838949&excludeEventConfig=ExcludeIfFromFullRecPage
# 1108th. Schmitz, Christian has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C6cNBTj6kgBBiSesTKE&author_name=Schmidt, M&dais_id=177532&excludeEventConfig=ExcludeIfFromFullRecPage
# 1109th. Schmidt, Martin has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C6cNBTj6kgBBiSesTKE&author_name=Reinecke, S&dais_id=8992912&excludeEventConfig=ExcludeIfFromFullRecPage
# 1110th. Reinecke, Sven has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C55iavYflZgQ79jlv1m&author_name=SMALL, I&dais_id=28573295&excludeEventConfig=ExcludeIfFromFullRecPage
# 1111th. SMALL, I has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C61st5TYVp41zpQGfsW&author_name=Janakiraman, R&dais_id=2484279&excludeEventConfig=ExcludeIfFromFullRecPage
# 1112th. Janakiraman, Ramkumar has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C61st5TYVp41zpQGfsW&author_name=Dutta, S&dais_id=763871&excludeEventConfig=ExcludeIfFromFullRecPage
# 1113th. Dutta, Shantanu has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C5gyV5mWQOtnHWxZ9Bb&author_name=Yip, WN&dais_id=13953496&excludeEventConfig=ExcludeIfFromFullRecPage
# 1114th. Yip, Winnie has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F1xdGqDWal7RdH3XUCM&author_name=Lumme, A&dais_id=19858324&excludeEventConfig=ExcludeIfFromFullRecPage
# 1115th. Lumme, A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E12wh76HKnf6bnizBX1&author_name=Barr, D&dais_id=8416565&excludeEventConfig=ExcludeIfFromFullRecPage
# 1116th. Barr, D has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E12wh76HKnf6bnizBX1&author_name=Breedon, F&dais_id=7094056&excludeEventConfig=ExcludeIfFromFullRecPage
# 1117th. Breedon, F has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4colAW5vJg9m2MWHsZ&author_name=Shearer, A&dais_id=2000486&excludeEventConfig=ExcludeIfFromFullRecPage
# 1118th. Shearer, A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E5HR99qR4pSF14f9YHp&author_name=De Waele, K&dais_id=30194121&excludeEventConfig=ExcludeIfFromFullRecPage
# 1119th. De Waele, K has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E5HR99qR4pSF14f9YHp&author_name=Desbrieres, P&dais_id=14268690&excludeEventConfig=ExcludeIfFromFullRecPage
# 1120th. Desbrieres, P has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E5HR99qR4pSF14f9YHp&author_name=Beekman, A&dais_id=29205858&excludeEventConfig=ExcludeIfFromFullRecPage
# 1121th. Beekman, A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C2MgkGv9gtjhr6YtBEO&author_name=Nicolay, CR&dais_id=8914431&excludeEventConfig=ExcludeIfFromFullRecPage
# 1122th. Nicolay, C R has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C2MgkGv9gtjhr6YtBEO&author_name=Purkayastha, S&dais_id=176899&excludeEventConfig=ExcludeIfFromFullRecPage
# 1123th. Purkayastha, S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C2MgkGv9gtjhr6YtBEO&author_name=Greenhalgh, A&dais_id=16931763&excludeEventConfig=ExcludeIfFromFullRecPage
# 1124th. Greenhalgh, A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C2MgkGv9gtjhr6YtBEO&author_name=Benn, J&dais_id=1495735&excludeEventConfig=ExcludeIfFromFullRecPage
# 1125th. Benn, J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C31J2cTZmM823ciuFXX&author_name=Valente, G&dais_id=1816084&excludeEventConfig=ExcludeIfFromFullRecPage
# 1126th. Valente, Giorgio has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D2PZuxKhYifBdUbCj8R&author_name=JARRETT, M&dais_id=9769642&excludeEventConfig=ExcludeIfFromFullRecPage
# 1127th. JARRETT, M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F1gx5DbpRBhZDl8Azij&author_name=Doyle, C&dais_id=3869240&excludeEventConfig=ExcludeIfFromFullRecPage
# 1128th. Doyle, Cathal has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F1gx5DbpRBhZDl8Azij&author_name=Matthews, R&dais_id=3778930&excludeEventConfig=ExcludeIfFromFullRecPage
# 1129th. Matthews, Rachel has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Thomas, R&dais_id=4529588&excludeEventConfig=ExcludeIfFromFullRecPage
# 1130th. Thomas, Ranjeeta has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Burger, R&dais_id=2156265&excludeEventConfig=ExcludeIfFromFullRecPage
# 1131th. Burger, Ronelle has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Harper, A&dais_id=5724593&excludeEventConfig=ExcludeIfFromFullRecPage
# 1132th. Harper, Abigail has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Kanema, S&dais_id=15284489&excludeEventConfig=ExcludeIfFromFullRecPage
# 1133th. Kanema, Sarah has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Mwenge, L&dais_id=5873862&excludeEventConfig=ExcludeIfFromFullRecPage
# 1134th. Mwenge, Lawrence has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Vanqa, N&dais_id=23161977&excludeEventConfig=ExcludeIfFromFullRecPage
# 1135th. Vanqa, Nosivuyile has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Bell-Mandla, N&dais_id=17357920&excludeEventConfig=ExcludeIfFromFullRecPage
# 1136th. BellMandla, Nomtha has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Floyd, S&dais_id=256385&excludeEventConfig=ExcludeIfFromFullRecPage
# 1137th. Floyd, Sian has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Bock, P&dais_id=1116118&excludeEventConfig=ExcludeIfFromFullRecPage
# 1138th. Bock, Peter has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Ayles, H&dais_id=304645&excludeEventConfig=ExcludeIfFromFullRecPage
# 1139th. Ayles, Helen has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Beyers, N&dais_id=77260&excludeEventConfig=ExcludeIfFromFullRecPage
# 1140th. Beyers, Nulda has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Donnell, D&dais_id=157190&excludeEventConfig=ExcludeIfFromFullRecPage
# 1141th. Donnell, Deborah has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Fidler, S&dais_id=100822&excludeEventConfig=ExcludeIfFromFullRecPage
# 1142th. Fidler, Sarah has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6aKGaPsdUzefgcaiVY&author_name=Hayes, R&dais_id=20994&excludeEventConfig=ExcludeIfFromFullRecPage
# 1143th. Hayes, Richard has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C3E8SmftoWUL95VK6PA&author_name=Vohora, A&dais_id=11471808&excludeEventConfig=ExcludeIfFromFullRecPage
# 1144th. Vohora, A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D2ZZ8spc6ZwW784CYk2&author_name=Bleaney, M&dais_id=217972&excludeEventConfig=ExcludeIfFromFullRecPage
# 1145th. Bleaney, M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C6dQvyzyxAToRElLNV3&author_name=Le Grand, J&dais_id=16217364&excludeEventConfig=ExcludeIfFromFullRecPage
# 1146th. Le Grand, J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C6cUQdfG6zke8pgOwNY&author_name=Bernardo, AE&dais_id=2164528&excludeEventConfig=ExcludeIfFromFullRecPage
# 1147th. Bernardo, AE has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C6cUQdfG6zke8pgOwNY&author_name=Welch, I&dais_id=920098&excludeEventConfig=ExcludeIfFromFullRecPage
# 1148th. Welch, I has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E5exiWZQCxnaZWdVrfj&author_name=Jackwerth, J&dais_id=14559386&excludeEventConfig=ExcludeIfFromFullRecPage
# 1149th. Jackwerth, J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4lLAfOJ3Nrv5EjVAqk&author_name=Heide, J&dais_id=21567700&excludeEventConfig=ExcludeIfFromFullRecPage
# 1150th. Heide, Jan has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C3BpSMt1sjtDFYoNpgW&author_name=Vedolin, A&dais_id=6005562&excludeEventConfig=ExcludeIfFromFullRecPage
# 1151th. Vedolin, Andrea has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C2ojD7wqZoWc9JOKdwj&author_name=LOCKLEY, H&dais_id=26349181&excludeEventConfig=ExcludeIfFromFullRecPage
# 1152th. LOCKLEY, H has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1UDpGUHx5NXOUOKiqj&author_name=Seru, A&dais_id=1878638&excludeEventConfig=ExcludeIfFromFullRecPage
# 1153th. Seru, Amit has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E5ogBJ1RxxWNmJq2Zuj&author_name=Blumstein, C&dais_id=3147372&excludeEventConfig=ExcludeIfFromFullRecPage
# 1154th. Blumstein, Carl has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4r1l9BLOZbyTOiX2HX&author_name=Villani, E&dais_id=8742544&excludeEventConfig=ExcludeIfFromFullRecPage
# 1155th. Villani, Elisa has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4r1l9BLOZbyTOiX2HX&author_name=Greco, L&dais_id=5094066&excludeEventConfig=ExcludeIfFromFullRecPage
# 1156th. Greco, Luciano has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6HaXJyqGlxqSDFTwrO&author_name=Chakrabarti, R&dais_id=2707781&excludeEventConfig=ExcludeIfFromFullRecPage
# 1157th. Chakrabarti, Rajesh has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6HaXJyqGlxqSDFTwrO&author_name=De, S&dais_id=11012410&excludeEventConfig=ExcludeIfFromFullRecPage
# 1158th. De, Sankar has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6HaXJyqGlxqSDFTwrO&author_name=Qian, MJ&dais_id=3724974&excludeEventConfig=ExcludeIfFromFullRecPage
# 1159th. Qian, Meijun has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F45QxlIoKXBWmREQkT8&author_name=Sambanis, N&dais_id=1529652&excludeEventConfig=ExcludeIfFromFullRecPage
# 1160th. Sambanis, Nicholas has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E5rlmwz1cWKz4hZsYzP&author_name=Lauridsen, J&dais_id=592222&excludeEventConfig=ExcludeIfFromFullRecPage
# 1161th. Lauridsen, J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6X77d6cUVY1yLZ3jFm&author_name=Holstein, J&dais_id=19222192&excludeEventConfig=ExcludeIfFromFullRecPage
# 1162th. Holstein, Jeannie has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6tDFThm3r9NAJzddtG&author_name=ODONNELL, O&dais_id=471134&excludeEventConfig=ExcludeIfFromFullRecPage
# 1163th. ODONNELL, O has been added

# %% [markdown]
# #  Re-scraping the missing authors

# %%
author = pd.read_csv('./data/author_info_recheck.csv')
WOS_df = pd.read_pickle('./data/WOS_scraped_df_ver3.pkl')

# %% [markdown]
# ## Find the missing authors

# %%
# adding the index of those authors that could not be scraped due to the network issue
researching_index = []
for idx, names in enumerate(WOS_df.co_author1):
    for name in names:
        if not name.lower() in list(author.name_id):
            researching_index.append(idx)

WOS_df.loc[researching_index, :].to_pickle('./data/WOS_df_author.pkl')

# %% [markdown]
# ## Re-scrape

# %%
#Same code as above
def coauthors_info_recheck():

    WOS_df = pd.read_pickle('./data/WOS_df_author.pkl')
    WOS_df_set_URL = list(set(WOS_df.WOS_URL))
    
    author_info = pd.read_csv('./data/author_info_recheck.csv')
            
    for url in WOS_df_set_URL:
        ids = ['id']
        selected_id = random.choice(ids)
        passwords = ['pss']
        selected_pass = passwords[ids.index(selected_id)]

        #log-in page
        #Activate the Chrome Browser
        chrome_options = Options()
        chrome_options.add_argument('--lang=en-us')
        driver = webdriver.Chrome(chrome_options=chrome_options,executable_path=r"C:/Users/seong/Downloads/chrome/chromedriver")
        driver.get('https://login.webofknowledge.com/error/Error?PathInfo=%2F&Error=IPError')
        driver.implicitly_wait(5)
        driver.find_element_by_name('username').send_keys(selected_id) #email id
        driver.find_element_by_name('password').send_keys(selected_pass) #password
        driver.implicitly_wait(5)
        driver.find_element_by_xpath('//*[@id="WoKerror"]/div/table[2]/tbody/tr/td[2]/form[1]/table/tbody/tr[3]/td[2]/a/button').click() #click
        try:
            driver.find_element_by_xpath('//*[@id="WoKerror"]/div/table[2]/tbody/tr/td[2]/p/a[1]').click() #exception log-in
        except:
            pass
        driver.get(url)
        driver.implicitly_wait(5)
        
        # Click the bar to see the extra authors
        try:
            driver.find_element_by_xpath('//*[@id="show_more_authors_authors_txt_label"]/a').click()
            driver.implicitly_wait(5)
        except:
            pass
        
        author_info = author_info.astype('object')
        driver.implicitly_wait(5)
        soup = BeautifulSoup(driver.page_source, "html.parser")
        url_parsing = soup.find_all(title=["Find more records by this author"])
        author_parsing = soup.select("a")
        
        #url list
        authors_urls = ['http://apps.webofknowledge.com'+str(u.attrs['href'])for u in url_parsing if bool(re.search(r'[OneClickSearch.do?product=WOS&search_mode]', str(u.attrs['href'])))]
        #author name list                                                                             
        authors_id = [u.string.lower() for u in url_parsing if bool(re.search(r'[OneClickSearch.do?product=WOS&search_mode]', str(u.attrs['href'])))]
        
        authors_uniq = []
        for i in author_parsing:
            try:
                if bool(re.search(r'^ \(' ,i.next_sibling)):
                    authors_uniq.append(re.sub('[^A-Za-z0-9, ]+', "", i.next_sibling).strip())
            except:
                pass        

        if len(authors_urls) == 0:
            continue
        
        for idx, u in enumerate(authors_urls):
            if authors_id[idx] in list(author_info.name_id):
                continue 
            else:
                #reaching the publication list 
                driver.get(u)
                driver.implicitly_wait(15)
                try:
                    #reaching the author summary page
                    driver.find_element_by_xpath('//*[@id="view_citation_report_image_placeholder"]/div/nobr/a').click()
                    driver.implicitly_wait(15)
                except:
                    continue
                
                citation_report = BeautifulSoup(driver.page_source, "html.parser")
                values = citation_report.find_all('em',{'class':re.compile('[commafy]')})[1:]
                
                row_num = author_info.shape[0]
                author_info.loc[row_num,'publication_url'] = url
                author_info.loc[row_num,'name'] = authors_uniq[idx]
                author_info.loc[row_num,'name_id'] = authors_id[idx]
                author_info.loc[row_num,'authors_url'] = str(u)
                print(author_info.loc[row_num,'authors_url'])
                for v, c in zip(values, author_info.columns[4:]):
                    author_info.loc[row_num, c] = v.string.strip().replace(',','')
                print("%sth. %s has been added" %(author_info.shape[0], authors_uniq[idx]))
        author_info.to_csv('./data/author_info_recheck.csv', index = None)
        driver.close()
    driver.quit()

# %%
coauthors_info_recheck()
# Out:
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E5QgRdIX5XVzQlNpjLN&author_name=Perkins, A&dais_id=29124529&excludeEventConfig=ExcludeIfFromFullRecPage
# 1547th. Perkins, A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E58heHB2yawWMrFxNFN&author_name=Prashantham, S&dais_id=1447371&excludeEventConfig=ExcludeIfFromFullRecPage
# 1548th. Prashantham, Shameen has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E3uAUCYYCn1HxcokhKQ&author_name=Szymanski, S&dais_id=417882&excludeEventConfig=ExcludeIfFromFullRecPage
# 1549th. Szymanski, Stefan has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6BoCtokGRPQFlBaLVh&author_name=Roper, S&dais_id=327278&excludeEventConfig=ExcludeIfFromFullRecPage
# 1550th. Roper, Stephen has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6BoCtokGRPQFlBaLVh&author_name=Carter, S&dais_id=658272&excludeEventConfig=ExcludeIfFromFullRecPage
# 1551th. Carter, Sara has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E3QIXfVwny4dQ4O31rV&author_name=Wu, PC&dais_id=5918643&excludeEventConfig=ExcludeIfFromFullRecPage
# 1552th. Wu, PeiChuan has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E55IZTcHBbaWQeMNVBE&author_name=Boselie, P&dais_id=1523710&excludeEventConfig=ExcludeIfFromFullRecPage
# 1553th. Boselie, P has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D3aXSRLGdN3WghaE4UM&author_name=Schildt, H&dais_id=5415234&excludeEventConfig=ExcludeIfFromFullRecPage
# 1554th. Schildt, Henri has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6Q9L9WfwxSLP6a4dMr&author_name=Liu, Y&dais_id=8640824&excludeEventConfig=ExcludeIfFromFullRecPage
# 1555th. Liu, Yeyi has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6Q9L9WfwxSLP6a4dMr&author_name=Chun, HEH&dais_id=29722499&excludeEventConfig=ExcludeIfFromFullRecPage
# 1556th. Chun, Hae Eun Helen has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E5KuZHmmU7wbJnfMH9k&author_name=Fukuda, S&dais_id=965800&excludeEventConfig=ExcludeIfFromFullRecPage
# 1557th. Fukuda, Shinichi has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E5KuZHmmU7wbJnfMH9k&author_name=Hoshi, T&dais_id=771048&excludeEventConfig=ExcludeIfFromFullRecPage
# 1558th. Hoshi, Takeo has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E5KuZHmmU7wbJnfMH9k&author_name=Miyajima, H&dais_id=2626792&excludeEventConfig=ExcludeIfFromFullRecPage
# 1559th. Miyajima, Hideaki has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F515Sx6y8Aaqw8vvR8z&author_name=Eastwood, JP&dais_id=239656&excludeEventConfig=ExcludeIfFromFullRecPage
# 1560th. Eastwood, J P has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F515Sx6y8Aaqw8vvR8z&author_name=Hapgood, MA&dais_id=429093&excludeEventConfig=ExcludeIfFromFullRecPage
# 1561th. Hapgood, M A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F515Sx6y8Aaqw8vvR8z&author_name=Green, L&dais_id=5582294&excludeEventConfig=ExcludeIfFromFullRecPage
# 1562th. Green, L has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F515Sx6y8Aaqw8vvR8z&author_name=Bisi, MM&dais_id=595763&excludeEventConfig=ExcludeIfFromFullRecPage
# 1563th. Bisi, M M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F515Sx6y8Aaqw8vvR8z&author_name=Bentley, RD&dais_id=1025629&excludeEventConfig=ExcludeIfFromFullRecPage
# 1564th. Bentley, R D has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F515Sx6y8Aaqw8vvR8z&author_name=Wicks, R&dais_id=1377530&excludeEventConfig=ExcludeIfFromFullRecPage
# 1565th. Wicks, R has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F515Sx6y8Aaqw8vvR8z&author_name=McKinnell, LA&dais_id=430082&excludeEventConfig=ExcludeIfFromFullRecPage
# 1566th. McKinnell, L A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F515Sx6y8Aaqw8vvR8z&author_name=Gibbs, M&dais_id=22311905&excludeEventConfig=ExcludeIfFromFullRecPage
# 1567th. Gibbs, M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F515Sx6y8Aaqw8vvR8z&author_name=Burnett, C&dais_id=27162542&excludeEventConfig=ExcludeIfFromFullRecPage
# 1568th. Burnett, C has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6yY4DWOpDeitje8vp9&author_name=Koul, HL&dais_id=285105&excludeEventConfig=ExcludeIfFromFullRecPage
# 1569th. Koul, Hira L has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D3FVQoybiCRHr2Rp4vH&author_name=Abramavicius, S&dais_id=21079758&excludeEventConfig=ExcludeIfFromFullRecPage
# 1570th. Abramavicius, Sarunas has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6uSxTFhQU5fTsrKGZe&author_name=Renault, M&dais_id=31247171&excludeEventConfig=ExcludeIfFromFullRecPage
# 1571th. Renault, M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6uSxTFhQU5fTsrKGZe&author_name=Fontes, M&dais_id=1545748&excludeEventConfig=ExcludeIfFromFullRecPage
# 1572th. Fontes, M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D538zVJq9uDJojLb81Y&author_name=Menguc, B&dais_id=10494220&excludeEventConfig=ExcludeIfFromFullRecPage
# 1573th. Menguc, B has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D4KXjuSEY4QiAKmUxpg&author_name=KAURANEN, I&dais_id=3596091&excludeEventConfig=ExcludeIfFromFullRecPage
# 1574th. KAURANEN, I has been added
# http://apps.webofknowledge.com/OneClickSearch.do?product=WOS&search_mode=OneClickSearch&excludeEventConfig=ExcludeIfFromFullRecPage&colName=WOS&SID=F5KAQr6vlu5k6Pn4JIx&field=AU&value=Shaikh, M
# 1575th. Shaikh, Mujaheed has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D29LjpmjKEDcX3B35LE&author_name=Di Domenico, M&dais_id=2060998&excludeEventConfig=ExcludeIfFromFullRecPage
# 1576th. Di Domenico, MariaLaura has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D4XmKAhf5TtuywIlbqC&author_name=Iacone, F&dais_id=2875684&excludeEventConfig=ExcludeIfFromFullRecPage
# 1577th. Iacone, Fabrizio has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F2Rzc1iXexGXdPOx75R&author_name=Verspagen, B&dais_id=601029&excludeEventConfig=ExcludeIfFromFullRecPage
# 1578th. Verspagen, Bart has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6SBf8RsfjpyEHoGogx&author_name=McCormack, J&dais_id=1222606&excludeEventConfig=ExcludeIfFromFullRecPage
# 1579th. McCormack, John has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6SBf8RsfjpyEHoGogx&author_name=Smith, S&dais_id=1043252&excludeEventConfig=ExcludeIfFromFullRecPage
# 1580th. Smith, Sarah has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6GVa2TKZYCazF1eEc9&author_name=Rechel, B&dais_id=435260&excludeEventConfig=ExcludeIfFromFullRecPage
# 1581th. Rechel, Bernd has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E67ThZwZq5qmmhw5LuN&author_name=Xu, HP&dais_id=2311559&excludeEventConfig=ExcludeIfFromFullRecPage
# 1582th. Xu, Haoping has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4HR39xnMgGky6o7tQ9&author_name=Carnabuci, G&dais_id=3459997&excludeEventConfig=ExcludeIfFromFullRecPage
# 1583th. Carnabuci, Gianluca has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4HR39xnMgGky6o7tQ9&author_name=Dioszegi, B&dais_id=26985071&excludeEventConfig=ExcludeIfFromFullRecPage
# 1584th. Dioszegi, Balint has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6uxs2OmbzWd7GoHdMB&author_name=Fildes, R&dais_id=317829&excludeEventConfig=ExcludeIfFromFullRecPage
# 1585th. Fildes, R has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6uxs2OmbzWd7GoHdMB&author_name=Hibon, M&dais_id=2766405&excludeEventConfig=ExcludeIfFromFullRecPage
# 1586th. Hibon, M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6uxs2OmbzWd7GoHdMB&author_name=Makridakis, S&dais_id=567624&excludeEventConfig=ExcludeIfFromFullRecPage
# 1587th. Makridakis, S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4xLgMy15XsVJ91dPGC&author_name=Hameri, AP&dais_id=926299&excludeEventConfig=ExcludeIfFromFullRecPage
# 1588th. Hameri, AP has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4xLgMy15XsVJ91dPGC&author_name=Nordberg, M&dais_id=7348817&excludeEventConfig=ExcludeIfFromFullRecPage
# 1589th. Nordberg, M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D46hbLZzIvEvl6IpRSb&author_name=Barbero, JL&dais_id=414042&excludeEventConfig=ExcludeIfFromFullRecPage
# 1590th. Barbero, Jose L has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D46hbLZzIvEvl6IpRSb&author_name=Casillas, JC&dais_id=1929917&excludeEventConfig=ExcludeIfFromFullRecPage
# 1591th. Casillas, Jose C has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D46hbLZzIvEvl6IpRSb&author_name=Garcia, AR&dais_id=11789709&excludeEventConfig=ExcludeIfFromFullRecPage
# 1592th. Ramos Garcia, Alicia has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2CmlEodwVWT13Bm5mq&author_name=Burges, S&dais_id=21101316&excludeEventConfig=ExcludeIfFromFullRecPage
# 1593th. Burges, S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D2IJhRKeJfUznBkxepF&author_name=Acs, ZJ&dais_id=139450&excludeEventConfig=ExcludeIfFromFullRecPage
# 1594th. Acs, Zoltan J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D2IJhRKeJfUznBkxepF&author_name=Szerb, L&dais_id=2716981&excludeEventConfig=ExcludeIfFromFullRecPage
# 1595th. Szerb, Laszlo has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F5YpfQCiaekBujXcoOQ&author_name=Sudarsanam, S&dais_id=4218262&excludeEventConfig=ExcludeIfFromFullRecPage
# 1596th. Sudarsanam, Sudi has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F5YpfQCiaekBujXcoOQ&author_name=Huang, J&dais_id=4580185&excludeEventConfig=ExcludeIfFromFullRecPage
# 1597th. Huang, Jian has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2bbzr7YIJCaaCHwjuW&author_name=Wright, J&dais_id=2904830&excludeEventConfig=ExcludeIfFromFullRecPage
# 1598th. Wright, J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F55KazwG3RSESmWkQRi&author_name=Jaaskelainen, M&dais_id=6805803&excludeEventConfig=ExcludeIfFromFullRecPage
# 1599th. Jaaskelainen, Mikko has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C2bKu6ikgrdvztaUtEY&author_name=Altanlar, A&dais_id=8309303&excludeEventConfig=ExcludeIfFromFullRecPage
# 1600th. Altanlar, Ali has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C3sqLTMFHKicouWhmyD&author_name=Gomulya, D&dais_id=5843284&excludeEventConfig=ExcludeIfFromFullRecPage
# 1601th. Gomulya, David has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D3oi6QQLSEYXGLsXOVZ&author_name=deHolan, PM&dais_id=23339596&excludeEventConfig=ExcludeIfFromFullRecPage
# 1602th. deHolan, PM has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F5OG7Z48AtLOQlrn4Xu&author_name=Hobbs, B&dais_id=166411&excludeEventConfig=ExcludeIfFromFullRecPage
# 1603th. Hobbs, Benjamin has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F5OG7Z48AtLOQlrn4Xu&author_name=Oren, S&dais_id=1617729&excludeEventConfig=ExcludeIfFromFullRecPage
# 1604th. Oren, Shmuel has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F5OG7Z48AtLOQlrn4Xu&author_name=Siddiqui, A&dais_id=836238&excludeEventConfig=ExcludeIfFromFullRecPage
# 1605th. Siddiqui, Afzal has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C3cChvTr6lSqFb2GLPL&author_name=Yatchew, A&dais_id=1162866&excludeEventConfig=ExcludeIfFromFullRecPage
# 1606th. Yatchew, Adonis has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F2gnLKW94gjWXrE8wuO&author_name=Golinski, A&dais_id=12690823&excludeEventConfig=ExcludeIfFromFullRecPage
# 1607th. Golinski, Adam has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D3aT9TFP5zS6c5p4Mnv&author_name=Federico, G&dais_id=3687045&excludeEventConfig=ExcludeIfFromFullRecPage
# 1608th. Federico, Giulio has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D4hIGlUF4YpMS4wF84Y&author_name=Liu, YY&dais_id=8640824&excludeEventConfig=ExcludeIfFromFullRecPage
# 1609th. Liu, Yeyi has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D4hIGlUF4YpMS4wF84Y&author_name=Jia, H&dais_id=9619493&excludeEventConfig=ExcludeIfFromFullRecPage
# 1610th. Jia, He Michael has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C3joSBUoJo91oyyE37H&author_name=Timmermann, A&dais_id=317098&excludeEventConfig=ExcludeIfFromFullRecPage
# 1611th. Timmermann, Allan has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C3joSBUoJo91oyyE37H&author_name=Wermers, R&dais_id=1824110&excludeEventConfig=ExcludeIfFromFullRecPage
# 1612th. Wermers, Russ has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C3joSBUoJo91oyyE37H&author_name=White, H&dais_id=5441351&excludeEventConfig=ExcludeIfFromFullRecPage
# 1613th. White, Hal has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6AinPy424GtQJCa5UD&author_name=Iben, A&dais_id=19239103&excludeEventConfig=ExcludeIfFromFullRecPage
# 1614th. Iben, A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6ZS48DSpIIgMxD6vqk&author_name=Ng, S&dais_id=644226&excludeEventConfig=ExcludeIfFromFullRecPage
# 1615th. Ng, S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6WOYk8XXiGGYHIScoE&author_name=Antipov, A&dais_id=25652243&excludeEventConfig=ExcludeIfFromFullRecPage
# 1616th. Antipov, A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1J5lZZd6VLsExXuSRb&author_name=Michelacci, C&dais_id=2426175&excludeEventConfig=ExcludeIfFromFullRecPage
# 1617th. Michelacci, C has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F69ztoZXlajY2ekMzxs&author_name=Vuola, O&dais_id=9045565&excludeEventConfig=ExcludeIfFromFullRecPage
# 1618th. Vuola, O has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E69w1W9wVOxrNEdL6c6&author_name=Harris, R&dais_id=5175776&excludeEventConfig=ExcludeIfFromFullRecPage
# 1619th. Harris, R has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1mYYuVjn6v1PJ13Nl6&author_name=Renedo, A&dais_id=3186209&excludeEventConfig=ExcludeIfFromFullRecPage
# 1620th. Renedo, Alicia has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1mYYuVjn6v1PJ13Nl6&author_name=Marston, CA&dais_id=1243398&excludeEventConfig=ExcludeIfFromFullRecPage
# 1621th. Marston, Cicely Alice has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E29GlTbuGR1PPaX162H&author_name=Devers, CE&dais_id=2498617&excludeEventConfig=ExcludeIfFromFullRecPage
# 1622th. Devers, Cynthia E has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E29GlTbuGR1PPaX162H&author_name=Dewett, T&dais_id=3545199&excludeEventConfig=ExcludeIfFromFullRecPage
# 1623th. Dewett, Todd has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E29GlTbuGR1PPaX162H&author_name=Belsito, CA&dais_id=8582889&excludeEventConfig=ExcludeIfFromFullRecPage
# 1624th. Belsito, Carrie A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1VPPhQ5ZEnsQEH9IR1&author_name=Muldur, U&dais_id=24985229&excludeEventConfig=ExcludeIfFromFullRecPage
# 1625th. Muldur, U has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1dg2TQ5nqPzREqCUSz&author_name=Hardeman, S&dais_id=11337647&excludeEventConfig=ExcludeIfFromFullRecPage
# 1626th. Hardeman, Sjoerd has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1dg2TQ5nqPzREqCUSz&author_name=Frenken, K&dais_id=343858&excludeEventConfig=ExcludeIfFromFullRecPage
# 1627th. Frenken, Koen has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1dg2TQ5nqPzREqCUSz&author_name=Nomaler, O&dais_id=4365747&excludeEventConfig=ExcludeIfFromFullRecPage
# 1628th. Nomaler, Onder has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4A6AF3os99Hgmsyvzf&author_name=Zikes, F&dais_id=3444399&excludeEventConfig=ExcludeIfFromFullRecPage
# 1629th. Zikes, Filip has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C6rz3XjaXSTZI76DR93&author_name=de Haan, J&dais_id=112953&excludeEventConfig=ExcludeIfFromFullRecPage
# 1630th. de Haan, J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C6rz3XjaXSTZI76DR93&author_name=Pagano, M&dais_id=637017&excludeEventConfig=ExcludeIfFromFullRecPage
# 1631th. Pagano, M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1NIxtymfndKE3WPqjx&author_name=Merla, A&dais_id=16162530&excludeEventConfig=ExcludeIfFromFullRecPage
# 1632th. Merla, Anna has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1NIxtymfndKE3WPqjx&author_name=Levaggi, R&dais_id=641136&excludeEventConfig=ExcludeIfFromFullRecPage
# 1633th. Levaggi, Rosella has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1NIxtymfndKE3WPqjx&author_name=Schulz, PJ&dais_id=133145&excludeEventConfig=ExcludeIfFromFullRecPage
# 1634th. Schulz, Peter J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1NIxtymfndKE3WPqjx&author_name=Auxilia, F&dais_id=1320286&excludeEventConfig=ExcludeIfFromFullRecPage
# 1635th. Auxilia, Francesco has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1NIxtymfndKE3WPqjx&author_name=Castaldi, S&dais_id=1479620&excludeEventConfig=ExcludeIfFromFullRecPage
# 1636th. Castaldi, Silvana has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1NIxtymfndKE3WPqjx&author_name=Gelatti, U&dais_id=305162&excludeEventConfig=ExcludeIfFromFullRecPage
# 1637th. Gelatti, Umberto has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4RgCRpMVtAX2lUUM3k&author_name=Danishevski, K&dais_id=2876105&excludeEventConfig=ExcludeIfFromFullRecPage
# 1638th. Danishevski, Kirill has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4RgCRpMVtAX2lUUM3k&author_name=Maltcev, V&dais_id=26249196&excludeEventConfig=ExcludeIfFromFullRecPage
# 1639th. Maltcev, Victor has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C6ItnrejuJmXjebOShP&author_name=Ayyagari, M&dais_id=3648004&excludeEventConfig=ExcludeIfFromFullRecPage
# 1640th. Ayyagari, Meghana has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C19jVAMSdNiuseCA65n&author_name=Zhang, YX&dais_id=27196&excludeEventConfig=ExcludeIfFromFullRecPage
# 1641th. Zhang, Yuxin has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4QFKauztSWSkYPuq39&author_name=Ludvigson, SC&dais_id=2896596&excludeEventConfig=ExcludeIfFromFullRecPage
# 1642th. Ludvigson, SC has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C3ndomqxfWGeY5Iu3KS&author_name=Donni, PL&dais_id=4334099&excludeEventConfig=ExcludeIfFromFullRecPage
# 1643th. Donni, Paolo Li has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1f5CLiNoaEUBVTqcyv&author_name=Veugelers, R&dais_id=763059&excludeEventConfig=ExcludeIfFromFullRecPage
# 1644th. Veugelers, Reinhilde has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E68LSQ9BvzEE2XEcD3m&author_name=Shan, SC&dais_id=19947071&excludeEventConfig=ExcludeIfFromFullRecPage
# 1645th. Shan, Susan Chenyu has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E68LSQ9BvzEE2XEcD3m&author_name=Zhao, MX&dais_id=1451698&excludeEventConfig=ExcludeIfFromFullRecPage
# 1646th. Zhao, Mengxin has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C1V5d2FAhOgEdtsUtfr&author_name=Feng, Y&dais_id=1970504&excludeEventConfig=ExcludeIfFromFullRecPage
# 1647th. Feng, Yan has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C1V5d2FAhOgEdtsUtfr&author_name=Pistollato, M&dais_id=6140927&excludeEventConfig=ExcludeIfFromFullRecPage
# 1648th. Pistollato, Michele has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C1V5d2FAhOgEdtsUtfr&author_name=Charlesworth, A&dais_id=5944156&excludeEventConfig=ExcludeIfFromFullRecPage
# 1649th. Charlesworth, Anita has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C1V5d2FAhOgEdtsUtfr&author_name=Sussex, J&dais_id=2067456&excludeEventConfig=ExcludeIfFromFullRecPage
# 1650th. Sussex, Jon has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4m3zUvRL7xaGwucxRR&author_name=Zaman, S&dais_id=7393260&excludeEventConfig=ExcludeIfFromFullRecPage
# 1651th. Zaman, Sameer has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4m3zUvRL7xaGwucxRR&author_name=Zaman, SS&dais_id=5788616&excludeEventConfig=ExcludeIfFromFullRecPage
# 1652th. Zaman, Saman Sara has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4m3zUvRL7xaGwucxRR&author_name=Kahlon, GK&dais_id=19706424&excludeEventConfig=ExcludeIfFromFullRecPage
# 1653th. Kahlon, Gurnaaz Kaur has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4m3zUvRL7xaGwucxRR&author_name=Naik, A&dais_id=29207317&excludeEventConfig=ExcludeIfFromFullRecPage
# 1654th. Naik, Aditi has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4m3zUvRL7xaGwucxRR&author_name=Jessel, AS&dais_id=10745715&excludeEventConfig=ExcludeIfFromFullRecPage
# 1655th. Jessel, Amar Singh has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4m3zUvRL7xaGwucxRR&author_name=Nanavati, N&dais_id=30822655&excludeEventConfig=ExcludeIfFromFullRecPage
# 1656th. Nanavati, Niraj has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4m3zUvRL7xaGwucxRR&author_name=Shah, A&dais_id=7850721&excludeEventConfig=ExcludeIfFromFullRecPage
# 1657th. Shah, Akash has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C1nyHILjkbO5ZeNqeks&author_name=Nwankwo, E&dais_id=25466749&excludeEventConfig=ExcludeIfFromFullRecPage
# 1658th. Nwankwo, Emeka has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E38VzyANnBIVRyRc6Xe&author_name=Patriotta, G&dais_id=2304073&excludeEventConfig=ExcludeIfFromFullRecPage
# 1659th. Patriotta, Gerardo has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E38VzyANnBIVRyRc6Xe&author_name=Castellano, A&dais_id=5150097&excludeEventConfig=ExcludeIfFromFullRecPage
# 1660th. Castellano, Anna has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4RSV9WkYMtzuXHxHvU&author_name=Albrighton, M&dais_id=22017878&excludeEventConfig=ExcludeIfFromFullRecPage
# 1661th. Albrighton, M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F44fFvp1SdcZZgcUDal&author_name=Enz, CA&dais_id=1094038&excludeEventConfig=ExcludeIfFromFullRecPage
# 1662th. Enz, Cathy A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1cyPDm6xvC4dY6Jx5r&author_name=El-Hilly, A&dais_id=24503226&excludeEventConfig=ExcludeIfFromFullRecPage
# 1663th. ElHilly, A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1cyPDm6xvC4dY6Jx5r&author_name=Iqbal, S&dais_id=11062557&excludeEventConfig=ExcludeIfFromFullRecPage
# 1664th. Iqbal, S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1uMHwbFEJ8Mze5CQtk&author_name=Griffith, R&dais_id=757058&excludeEventConfig=ExcludeIfFromFullRecPage
# 1665th. Griffith, Rachel has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1uMHwbFEJ8Mze5CQtk&author_name=Neely, A&dais_id=572520&excludeEventConfig=ExcludeIfFromFullRecPage
# 1666th. Neely, Andy has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2bOGUZznViK2cJnpMy&author_name=Buttice, V&dais_id=24431437&excludeEventConfig=ExcludeIfFromFullRecPage
# 1667th. Buttice, Vincenzo has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E3kL33vscLAxtDrMBN7&author_name=Cheng, IH&dais_id=6114483&excludeEventConfig=ExcludeIfFromFullRecPage
# 1668th. Cheng, IngHaw has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E3kL33vscLAxtDrMBN7&author_name=Xiong, W&dais_id=1278893&excludeEventConfig=ExcludeIfFromFullRecPage
# 1669th. Xiong, Wei has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2zIvdnTUKEudMXgYoD&author_name=Everaert, K&dais_id=12270029&excludeEventConfig=ExcludeIfFromFullRecPage
# 1670th. Everaert, K has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2zIvdnTUKEudMXgYoD&author_name=Delanghe, J&dais_id=22696&excludeEventConfig=ExcludeIfFromFullRecPage
# 1671th. Delanghe, J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2zIvdnTUKEudMXgYoD&author_name=Vanderkelen, M&dais_id=6128139&excludeEventConfig=ExcludeIfFromFullRecPage
# 1672th. Vanderkelen, M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2zIvdnTUKEudMXgYoD&author_name=Cornelis, K&dais_id=7947017&excludeEventConfig=ExcludeIfFromFullRecPage
# 1673th. Cornelis, K has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2zIvdnTUKEudMXgYoD&author_name=De Wachter, S&dais_id=180113&excludeEventConfig=ExcludeIfFromFullRecPage
# 1674th. De Wachter, S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2zIvdnTUKEudMXgYoD&author_name=Viaene, A&dais_id=14343946&excludeEventConfig=ExcludeIfFromFullRecPage
# 1675th. Viaene, A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2zIvdnTUKEudMXgYoD&author_name=De Ruyck, E&dais_id=20033145&excludeEventConfig=ExcludeIfFromFullRecPage
# 1676th. De Ruyck, E has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2zIvdnTUKEudMXgYoD&author_name=Oosterlinck, W&dais_id=5815120&excludeEventConfig=ExcludeIfFromFullRecPage
# 1677th. Oosterlinck, W has been added
# http://apps.webofknowledge.com/OneClickSearch.do?product=WOS&search_mode=OneClickSearch&excludeEventConfig=ExcludeIfFromFullRecPage&colName=WOS&SID=D2iVjhUur6SJqGLHwnf&field=AU&value=Redden, JP
# 1678th. Redden, Joseph P has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6SSDyACeq8zD3MDg5w&author_name=WATKINS, T&dais_id=11275430&excludeEventConfig=ExcludeIfFromFullRecPage
# 1679th. WATKINS, T has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4BrdLeII4e9PUA9pBJ&author_name=Abma, I&dais_id=10437110&excludeEventConfig=ExcludeIfFromFullRecPage
# 1680th. Abma, Inger has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4BrdLeII4e9PUA9pBJ&author_name=Jayanti, A&dais_id=2029473&excludeEventConfig=ExcludeIfFromFullRecPage
# 1681th. Jayanti, Anuradha has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4BrdLeII4e9PUA9pBJ&author_name=Mitra, S&dais_id=748753&excludeEventConfig=ExcludeIfFromFullRecPage
# 1682th. Mitra, Sandip has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6MknZ7H5iAzsGHM71K&author_name=Von Minckwitz, G&dais_id=8835911&excludeEventConfig=ExcludeIfFromFullRecPage
# 1683th. Von Minckwitz, G has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6MknZ7H5iAzsGHM71K&author_name=Seidman, AD&dais_id=135360&excludeEventConfig=ExcludeIfFromFullRecPage
# 1684th. Seidman, AD has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4wuW3ylLd9d8ijnZq8&author_name=Aghion, P&dais_id=289870&excludeEventConfig=ExcludeIfFromFullRecPage
# 1685th. Aghion, Philippe has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4wuW3ylLd9d8ijnZq8&author_name=Dechezlepretre, A&dais_id=3062527&excludeEventConfig=ExcludeIfFromFullRecPage
# 1686th. Dechezlepretre, Antoine has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4wuW3ylLd9d8ijnZq8&author_name=Hemous, D&dais_id=6163172&excludeEventConfig=ExcludeIfFromFullRecPage
# 1687th. Hemous, David has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1ALYbhDFqbrCJ6CW4F&author_name=Esteban-Bravo, M&dais_id=2669671&excludeEventConfig=ExcludeIfFromFullRecPage
# 1688th. EstebanBravo, Mercedes has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1ALYbhDFqbrCJ6CW4F&author_name=Vidal-Sanz, JM&dais_id=2769284&excludeEventConfig=ExcludeIfFromFullRecPage
# 1689th. VidalSanz, Jose M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2bANI4NL12W9CXSth4&author_name=Avarucci, M&dais_id=10780440&excludeEventConfig=ExcludeIfFromFullRecPage
# 1690th. Avarucci, Marco has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2bANI4NL12W9CXSth4&author_name=Beutner, E&dais_id=1229830&excludeEventConfig=ExcludeIfFromFullRecPage
# 1691th. Beutner, Eric has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6UXlshijePTqQ8oYwC&author_name=Uhlenbruck, K&dais_id=2506384&excludeEventConfig=ExcludeIfFromFullRecPage
# 1692th. Uhlenbruck, K has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E6UXlshijePTqQ8oYwC&author_name=Tihanyi, L&dais_id=741204&excludeEventConfig=ExcludeIfFromFullRecPage
# 1693th. Tihanyi, L has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6p67JBGgIYdeKhaUGA&author_name=Jarvis, O&dais_id=13922550&excludeEventConfig=ExcludeIfFromFullRecPage
# 1694th. Jarvis, Owen has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C2Rhd1WsoGrbsUFPCYZ&author_name=Bonjour, D&dais_id=17100103&excludeEventConfig=ExcludeIfFromFullRecPage
# 1695th. Bonjour, D has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C2Rhd1WsoGrbsUFPCYZ&author_name=Cherkas, LF&dais_id=703037&excludeEventConfig=ExcludeIfFromFullRecPage
# 1696th. Cherkas, LF has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C2Rhd1WsoGrbsUFPCYZ&author_name=Hawkes, DD&dais_id=3257376&excludeEventConfig=ExcludeIfFromFullRecPage
# 1697th. Hawkes, DD has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C2Rhd1WsoGrbsUFPCYZ&author_name=Spector, TD&dais_id=5195&excludeEventConfig=ExcludeIfFromFullRecPage
# 1698th. Spector, TD has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C17tngWknhuWEIuAWaR&author_name=Cull, R&dais_id=881775&excludeEventConfig=ExcludeIfFromFullRecPage
# 1699th. Cull, Robert has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C17tngWknhuWEIuAWaR&author_name=Senbet, L&dais_id=6330450&excludeEventConfig=ExcludeIfFromFullRecPage
# 1700th. Senbet, Lemma has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C17tngWknhuWEIuAWaR&author_name=Valenzuela, P&dais_id=3275468&excludeEventConfig=ExcludeIfFromFullRecPage
# 1701th. Valenzuela, Patricio has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E3oId7ZDXw6fEcThC6e&author_name=Ekkirala, S&dais_id=15884941&excludeEventConfig=ExcludeIfFromFullRecPage
# 1702th. Ekkirala, Srinivas has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4RlI8oXvZoTtNYWCmJ&author_name=Picard, J&dais_id=1914744&excludeEventConfig=ExcludeIfFromFullRecPage
# 1703th. Picard, J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4RlI8oXvZoTtNYWCmJ&author_name=Ward, SC&dais_id=219645&excludeEventConfig=ExcludeIfFromFullRecPage
# 1704th. Ward, S C has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4RlI8oXvZoTtNYWCmJ&author_name=Zumpe, R&dais_id=25931166&excludeEventConfig=ExcludeIfFromFullRecPage
# 1705th. Zumpe, R has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4RlI8oXvZoTtNYWCmJ&author_name=Meek, T&dais_id=1678533&excludeEventConfig=ExcludeIfFromFullRecPage
# 1706th. Meek, T has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4RlI8oXvZoTtNYWCmJ&author_name=Harrop-Griffiths, W&dais_id=871771&excludeEventConfig=ExcludeIfFromFullRecPage
# 1707th. HarropGriffiths, W has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1e5hX7uolO2H84ED18&author_name=Menini, D&dais_id=31654303&excludeEventConfig=ExcludeIfFromFullRecPage
# 1708th. Menini, D has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F2HyCxXKMace4i6u5oV&author_name=Reynolds, P&dais_id=2576594&excludeEventConfig=ExcludeIfFromFullRecPage
# 1709th. Reynolds, P has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F2HyCxXKMace4i6u5oV&author_name=Bosma, N&dais_id=2405636&excludeEventConfig=ExcludeIfFromFullRecPage
# 1710th. Bosma, N has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F2HyCxXKMace4i6u5oV&author_name=Hunt, S&dais_id=22489428&excludeEventConfig=ExcludeIfFromFullRecPage
# 1711th. Hunt, S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F2HyCxXKMace4i6u5oV&author_name=De Bono, N&dais_id=21822968&excludeEventConfig=ExcludeIfFromFullRecPage
# 1712th. De Bono, N has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F2HyCxXKMace4i6u5oV&author_name=Servais, I&dais_id=31133284&excludeEventConfig=ExcludeIfFromFullRecPage
# 1713th. Servais, I has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F2HyCxXKMace4i6u5oV&author_name=Lopez-Garcia, P&dais_id=16866559&excludeEventConfig=ExcludeIfFromFullRecPage
# 1714th. LopezGarcia, P has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F2HyCxXKMace4i6u5oV&author_name=Chin, N&dais_id=21994490&excludeEventConfig=ExcludeIfFromFullRecPage
# 1715th. Chin, N has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D4tEfDLE7bFh4gwClrT&author_name=Defazio, D&dais_id=13774606&excludeEventConfig=ExcludeIfFromFullRecPage
# 1716th. Defazio, Daniela has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1wcXXGZiUBVDi9ahqx&author_name=Murray, G&dais_id=3123542&excludeEventConfig=ExcludeIfFromFullRecPage
# 1717th. Murray, G has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C17MroLjY8fbl7dSYXH&author_name=Gauher, ST&dais_id=30353030&excludeEventConfig=ExcludeIfFromFullRecPage
# 1718th. Gauher, Salman T has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C17MroLjY8fbl7dSYXH&author_name=Khehar, R&dais_id=21870863&excludeEventConfig=ExcludeIfFromFullRecPage
# 1719th. Khehar, Ravi has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C17MroLjY8fbl7dSYXH&author_name=Rajput, G&dais_id=21149092&excludeEventConfig=ExcludeIfFromFullRecPage
# 1720th. Rajput, Gaurav has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C17MroLjY8fbl7dSYXH&author_name=Hayat, A&dais_id=12653053&excludeEventConfig=ExcludeIfFromFullRecPage
# 1721th. Hayat, Alia has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C17MroLjY8fbl7dSYXH&author_name=Bakshi, B&dais_id=24185690&excludeEventConfig=ExcludeIfFromFullRecPage
# 1722th. Bakshi, Bhavagaya has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C17MroLjY8fbl7dSYXH&author_name=Chawla, H&dais_id=19957094&excludeEventConfig=ExcludeIfFromFullRecPage
# 1723th. Chawla, Hanmeet has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C17MroLjY8fbl7dSYXH&author_name=Warrens, AN&dais_id=333686&excludeEventConfig=ExcludeIfFromFullRecPage
# 1724th. Warrens, Anthony N has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6E6XIJdXIxmD7Sz3OK&author_name=Hoernig, SH&dais_id=1632159&excludeEventConfig=ExcludeIfFromFullRecPage
# 1725th. Hoernig, Steffen H has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6WTlXzH2DgmqSL8GFL&author_name=Devigne, D&dais_id=15422961&excludeEventConfig=ExcludeIfFromFullRecPage
# 1726th. Devigne, David has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D3sY7UAOIviPyYINRwH&author_name=MacNeill, V&dais_id=5500407&excludeEventConfig=ExcludeIfFromFullRecPage
# 1727th. MacNeill, Virginia has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6uVZCYOPcdQvnhuQks&author_name=Parikh, P&dais_id=3733873&excludeEventConfig=ExcludeIfFromFullRecPage
# 1728th. Parikh, Priti has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1a9ggj8jjZCsckaJnn&author_name=Walsh, K&dais_id=5102433&excludeEventConfig=ExcludeIfFromFullRecPage
# 1729th. Walsh, Kathryn has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6N8U4RvhDLzvx3ej6L&author_name=vanDoorslaer, E&dais_id=3781645&excludeEventConfig=ExcludeIfFromFullRecPage
# 1730th. vanDoorslaer, E has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6N8U4RvhDLzvx3ej6L&author_name=Bleichrodt, H&dais_id=15870564&excludeEventConfig=ExcludeIfFromFullRecPage
# 1731th. Bleichrodt, H has been added
# http://apps.webofknowledge.com/OneClickSearch.do?product=WOS&search_mode=OneClickSearch&excludeEventConfig=ExcludeIfFromFullRecPage&colName=WOS&SID=F2pbpdBdzMawgcW9Ckx&field=AU&value=Li Donni, P
# 1732th. Li Donni, Paolo has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4Mt4iDBekaZ93QyqD5&author_name=Devinney, TM&dais_id=345650&excludeEventConfig=ExcludeIfFromFullRecPage
# 1733th. Devinney, Timothy M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4Mt4iDBekaZ93QyqD5&author_name=Johnson, G&dais_id=1821198&excludeEventConfig=ExcludeIfFromFullRecPage
# 1734th. Johnson, Gerry has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D1YZc18YYx6y9Wca7LI&author_name=Keeley, RH&dais_id=1988212&excludeEventConfig=ExcludeIfFromFullRecPage
# ...
# 1751th. Deakin, S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D3wrH5De7vMNcEAJ6jm&author_name=Dushnitsky, G&dais_id=2817523&excludeEventConfig=ExcludeIfFromFullRecPage
# 1752th. Dushnitsky, Gary has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F2gk1wIwqjpsInyWvE4&author_name=Scaramozzino, P&dais_id=1089175&excludeEventConfig=ExcludeIfFromFullRecPage
# 1753th. Scaramozzino, P has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4DmMjvul1eSGSuHyPD&author_name=Martin, F&dais_id=14195991&excludeEventConfig=ExcludeIfFromFullRecPage
# 1754th. Martin, F has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4rAovbxsoIkabnpfmK&author_name=Brostrom, A&dais_id=198113&excludeEventConfig=ExcludeIfFromFullRecPage
# 1755th. Brostrom, Anders has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4rAovbxsoIkabnpfmK&author_name=D'Este, P&dais_id=1447561&excludeEventConfig=ExcludeIfFromFullRecPage
# 1756th. DEste, Pablo has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4rAovbxsoIkabnpfmK&author_name=Krabel, S&dais_id=3863652&excludeEventConfig=ExcludeIfFromFullRecPage
# 1757th. Krabel, Stefan has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4rAovbxsoIkabnpfmK&author_name=Llerena, P&dais_id=1533943&excludeEventConfig=ExcludeIfFromFullRecPage
# 1758th. Llerena, Patrick has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4rAovbxsoIkabnpfmK&author_name=Lissoni, F&dais_id=1647160&excludeEventConfig=ExcludeIfFromFullRecPage
# 1759th. Lissoni, Franceso has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4rAovbxsoIkabnpfmK&author_name=Sobrero, M&dais_id=1828795&excludeEventConfig=ExcludeIfFromFullRecPage
# 1760th. Sobrero, Maurizio has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6XT23jEkSqyyzFH8GB&author_name=Cori, A&dais_id=1204312&excludeEventConfig=ExcludeIfFromFullRecPage
# 1761th. Cori, Anne has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6XT23jEkSqyyzFH8GB&author_name=Schaap, A&dais_id=1716610&excludeEventConfig=ExcludeIfFromFullRecPage
# 1762th. Schaap, Ab has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6XT23jEkSqyyzFH8GB&author_name=Sabapathy, K&dais_id=2257310&excludeEventConfig=ExcludeIfFromFullRecPage
# 1763th. Sabapathy, Kalpana has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6XT23jEkSqyyzFH8GB&author_name=Eaton, JW&dais_id=232984&excludeEventConfig=ExcludeIfFromFullRecPage
# 1764th. Eaton, Jeffrey W has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6XT23jEkSqyyzFH8GB&author_name=Griffith, S&dais_id=1874606&excludeEventConfig=ExcludeIfFromFullRecPage
# 1765th. Griffith, Sam has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6XT23jEkSqyyzFH8GB&author_name=Moore, A&dais_id=8700698&excludeEventConfig=ExcludeIfFromFullRecPage
# 1766th. Moore, Ayana has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6XT23jEkSqyyzFH8GB&author_name=Vermund, SH&dais_id=16076&excludeEventConfig=ExcludeIfFromFullRecPage
# 1767th. Vermund, Sten H has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6XT23jEkSqyyzFH8GB&author_name=Fraser, C&dais_id=148295&excludeEventConfig=ExcludeIfFromFullRecPage
# 1768th. Fraser, Christophe has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4drjLOuqWQdNr5XsfT&author_name=Gray, E&dais_id=3790107&excludeEventConfig=ExcludeIfFromFullRecPage
# 1769th. Gray, Emily has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D14x4uDyg8NlFVXwv8K&author_name=Rigg, J&dais_id=3163373&excludeEventConfig=ExcludeIfFromFullRecPage
# 1770th. Rigg, John has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4WbpqMk1DcFGgbbMIJ&author_name=Miyamoto, Y&dais_id=3942615&excludeEventConfig=ExcludeIfFromFullRecPage
# 1771th. Miyamoto, Yoshio has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4WbpqMk1DcFGgbbMIJ&author_name=Dykman, J&dais_id=25550251&excludeEventConfig=ExcludeIfFromFullRecPage
# 1772th. Dykman, Jackson has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2h3UyMETXb5mGawO2L&author_name=Kirsanova, T&dais_id=2121580&excludeEventConfig=ExcludeIfFromFullRecPage
# 1773th. Kirsanova, Tatiana has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F12wNRvORkCc3LeTK1x&author_name=Kringos, D&dais_id=8661794&excludeEventConfig=ExcludeIfFromFullRecPage
# 1774th. Kringos, Dionne has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F12wNRvORkCc3LeTK1x&author_name=Klazinga, NS&dais_id=228553&excludeEventConfig=ExcludeIfFromFullRecPage
# 1775th. Klazinga, Niek S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D6vV35cTBV6f8sWXHfp&author_name=Zhang, KJ&dais_id=9229136&excludeEventConfig=ExcludeIfFromFullRecPage
# 1776th. Zhang, Kuangjie has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D23yNBHlWGe5gCgQUwm&author_name=Sritrakul, W&dais_id=22256839&excludeEventConfig=ExcludeIfFromFullRecPage
# 1777th. Sritrakul, Worrawat has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F1A8npo2Yci3RTRaih7&author_name=Kramer, J&dais_id=462068&excludeEventConfig=ExcludeIfFromFullRecPage
# 1778th. Kraemer, Jan has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E2aUWx1p9B7QXoN6pUp&author_name=Boschma, R&dais_id=420152&excludeEventConfig=ExcludeIfFromFullRecPage
# 1779th. Boschma, Ron has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Howitt, P&dais_id=886679&excludeEventConfig=ExcludeIfFromFullRecPage
# 1780th. Howitt, Peter has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Yang, GZ&dais_id=1321&excludeEventConfig=ExcludeIfFromFullRecPage
# 1781th. Yang, GuangZhong has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Ashrafian, H&dais_id=62875&excludeEventConfig=ExcludeIfFromFullRecPage
# 1782th. Ashrafian, Hutan has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Blakemore, A&dais_id=11234372&excludeEventConfig=ExcludeIfFromFullRecPage
# 1783th. Blakemore, Alex has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Bull, AMJ&dais_id=106117&excludeEventConfig=ExcludeIfFromFullRecPage
# 1784th. Bull, Anthony M J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Car, J&dais_id=124273&excludeEventConfig=ExcludeIfFromFullRecPage
# 1785th. Car, Josip has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Conteh, L&dais_id=846026&excludeEventConfig=ExcludeIfFromFullRecPage
# 1786th. Conteh, Lesong has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Cooke, GS&dais_id=430354&excludeEventConfig=ExcludeIfFromFullRecPage
# 1787th. Cooke, Graham S has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Ford, N&dais_id=41345&excludeEventConfig=ExcludeIfFromFullRecPage
# 1788th. Ford, Nathan has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Gregson, SAJ&dais_id=15169113&excludeEventConfig=ExcludeIfFromFullRecPage
# 1789th. Gregson, Simon A J has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Kerr, K&dais_id=1473323&excludeEventConfig=ExcludeIfFromFullRecPage
# 1790th. Kerr, Karen has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Kulendran, M&dais_id=1735698&excludeEventConfig=ExcludeIfFromFullRecPage
# 1791th. Kulendran, Myutan has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Malkin, RA&dais_id=416173&excludeEventConfig=ExcludeIfFromFullRecPage
# 1792th. Malkin, Robert A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Matlin, S&dais_id=9224779&excludeEventConfig=ExcludeIfFromFullRecPage
# 1793th. Matlin, Stephen has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Merrifield, R&dais_id=1907508&excludeEventConfig=ExcludeIfFromFullRecPage
# 1794th. Merrifield, Robert has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Penfold, HA&dais_id=4800709&excludeEventConfig=ExcludeIfFromFullRecPage
# 1795th. Penfold, Hugh A has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Reid, SD&dais_id=3144484&excludeEventConfig=ExcludeIfFromFullRecPage
# 1796th. Reid, Steven D has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Stevens, MM&dais_id=31050&excludeEventConfig=ExcludeIfFromFullRecPage
# 1797th. Stevens, Molly M has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Templeton, MR&dais_id=367657&excludeEventConfig=ExcludeIfFromFullRecPage
# 1798th. Templeton, Michael R has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C4qCkogcD9Qvhw2YPzM&author_name=Wilson, E&dais_id=2295070&excludeEventConfig=ExcludeIfFromFullRecPage
# 1799th. Wilson, Elizabeth has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4zQbcEiIaQw9CB25S1&author_name=Cavaglia, S&dais_id=6687743&excludeEventConfig=ExcludeIfFromFullRecPage
# 1800th. Cavaglia, Stefano has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F4zQbcEiIaQw9CB25S1&author_name=Smith, B&dais_id=3404433&excludeEventConfig=ExcludeIfFromFullRecPage
# 1801th. Smith, Bryn has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6CRLPVWn4JkkP4hmSv&author_name=Vande Wiele, C&dais_id=13340316&excludeEventConfig=ExcludeIfFromFullRecPage
# 1802th. Vande Wiele, C has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6CRLPVWn4JkkP4hmSv&author_name=Hoebeke, P&dais_id=10579848&excludeEventConfig=ExcludeIfFromFullRecPage
# 1803th. Hoebeke, P has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6CRLPVWn4JkkP4hmSv&author_name=Dierckx, RA&dais_id=22216&excludeEventConfig=ExcludeIfFromFullRecPage
# 1804th. Dierckx, RA has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6CRLPVWn4JkkP4hmSv&author_name=Lameire, N&dais_id=29167822&excludeEventConfig=ExcludeIfFromFullRecPage
# 1805th. Lameire, N has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D57CYre2E9OI8mknDEt&author_name=Garnett, GP&dais_id=66822&excludeEventConfig=ExcludeIfFromFullRecPage
# 1806th. Garnett, Geoffrey P has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=D57CYre2E9OI8mknDEt&author_name=Piot, PK&dais_id=16606600&excludeEventConfig=ExcludeIfFromFullRecPage
# 1807th. Piot, Peter K has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=C3cZAxBjUngqQA1Ek9I&author_name=Gossage, D&dais_id=27423377&excludeEventConfig=ExcludeIfFromFullRecPage
# 1808th. Gossage, Denise has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1FSmpdENX3mQ4fdD2X&author_name=Verwaal, E&dais_id=2649951&excludeEventConfig=ExcludeIfFromFullRecPage
# 1809th. Verwaal, Ernst has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E4YW4jz5JKQYJQuN6x4&author_name=Beber, A&dais_id=4458672&excludeEventConfig=ExcludeIfFromFullRecPage
# 1810th. Beber, Alessandro has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=E1kJwxRgKm8DjDvVVFJ&author_name=SALKIN, GR&dais_id=2798596&excludeEventConfig=ExcludeIfFromFullRecPage
# 1811th. SALKIN, GR has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6A51N6E1Fz2DRbk6I6&author_name=Iskoujina, Z&dais_id=9034541&excludeEventConfig=ExcludeIfFromFullRecPage
# 1812th. Iskoujina, Zilia has been added
# http://apps.webofknowledge.com/DaisyOneClickSearch.do?product=WOS&search_mode=DaisyOneClickSearch&colName=WOS&SID=F6A51N6E1Fz2DRbk6I6&author_name=Garnett, P&dais_id=3700255&excludeEventConfig=ExcludeIfFromFullRecPage
# 1813th. Garnett, Philip has been added

# %%
df = pd.read_csv('./data/author_info_recheck.csv')
print("The number of the authors in parsing: ", df.name_id.nunique()) # No issing authors
# Out:
# The number of the authors in parsing:  1813

# %%
df.head()
# Out:
#                                      publication_url           name  \
# 0  http://gateway.webofknowledge.com/gateway/Gate...        Cosh, A
# 1  http://gateway.webofknowledge.com/gateway/Gate...      Hughes, A
# 2  http://gateway.webofknowledge.com/gateway/Gate...        Toms, S
# 3  http://gateway.webofknowledge.com/gateway/Gate...      Wright, M
# 4  http://gateway.webofknowledge.com/gateway/Gate...  Calzada, Joan
#
#       name_id                                        authors_url  \
# 0     cosh, a  http://apps.webofknowledge.com/DaisyOneClickSe...
# 1   hughes, a  http://apps.webofknowledge.com/DaisyOneClickSe...
# 2     toms, s  http://apps.webofknowledge.com/DaisyOneClickSe...
# 3   wright, m  http://apps.webofknowledge.com/DaisyOneClickSe...
# 4  calzada, j  http://apps.webofknowledge.com/DaisyOneClickSe...
#
#    ttl_publication  h-index  avg_citation_per_item  sum_of_times_cited  \
# 0                8        7                  42.63                 341
# 1               39       17                  32.54                1269
# 2               58       12                   7.78                 451
# 3              318       68                  49.07               15603
# 4               21        8                   6.48                 136
#
#    without_self_citations  citing_articles  without_self_citations_article
# 0                     339              330                             328
# 1                    1257             1211                            1202
# 2                     380              349                             322
# 3                   14181             9245                            8992
# 4                     129              128                             122
